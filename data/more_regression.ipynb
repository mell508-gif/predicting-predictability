# %%
import pandas as pd
import numpy as np

from pathlib import Path

print("Current folder:", Path.cwd())

for path in Path.cwd().iterdir():
    print(path.name)
# Out:
# Current folder: /Users/mell/predicting-predictability/data
# drugseq_registry_overlap_status.csv
# morgan_autoencoder_bottleneck_sweep_results.csv
# step1_compound_registry_clean.csv
# perturbseqr_morgan_fingerprints.csv
# umap_morgan_fingerprints.csv
# july_wraps.ipynb
# step3_multimodal
# morgan_autoencoder_latent64_vectors.csv
# drugseq_new_compounds_with_smiles.csv
# pca_morgan_fingerprints.csv
# .DS_Store
# umap_maccs_keys.csv
# representation_comparison_summary.csv
# morgan_to_maccs_summary.md
# pca_molecular_descriptors.csv
# part4_model_compound_index.csv
# tsne
# step1_fingerprints
# drug_metadata.parquet
# tahoe_registry_overlap_status.csv
# umap_combined_features
# objective_3_lincs_morgan_autoencoder.ipynb
# tahoe_compounds_with_smiles.csv
# step1_file_inventory.csv
# perturbseqr_molecular_descriptors.csv
# expanded_compound_structure_registry.csv
# DRUGseqr_metadata.tsv
# tahoe_new_compounds_with_smiles.csv
# perturbseqr_cactvs_pubchem_fingerprints.csv
# fingerprint_similarity_correlations.csv
# umap_metals
# step1_registry_summary.txt
# step2_signatures
# example_morgan_fingerprints.csv
# morgan_to_maccs_latent32_results_summary.csv
# descriptor_summary_statistics.csv
# pca_maccs_keys.csv
# fingerprint_similarity_summary.csv
# matched_drugmaster_consensus_names.csv
# pca_cactvs_pubchem_fingerprints.csv
# Step 2 Files
# umap_rings
# umap_cactvs_pubchem_fingerprints.csv
# .ipynb_checkpoints
# more_regression.ipynb
# umap_molecular_descriptors.csv
# morgan_full_50_epoch_bottleneck_summary.csv
# drugseq_usable_compounds_with_smiles.csv
# lincs_small_molecules_valid_unique.tsv
# step2_signature_embeddings
# lincs_morgan_fingerprints_2048.npy
# fingerprint_similarity_pairwise_sample.csv
# morgan_autoencoder_latent15.csv
# part4_predicting.ipynb
# morgan_full_50_epoch_loss_curves.csv
# part4_matched_consensus_signatures.csv.gz
# Step 1 Files
# perturbseqr_maccs_keys.csv
# perturbseqr_metadata
# drug_master.json
# morgan_autoencoder_latent15_umap.csv
# step1_compound_registry_expanded_clean_fast.csv
# step1_embeddings

# %%
import pandas as pd
from pathlib import Path

candidate_files = [
    "part4_model_compound_index.csv",
    "step3_multimodal_latent64_vectors.csv",
    "part4_matched_consensus_signatures.csv.gz",
]

for filename in candidate_files:
    path = Path(filename)

    print("\n" + "=" * 80)
    print(filename)
    print("Exists:", path.exists())

    if path.exists():
        preview = pd.read_csv(path, nrows=5)

        print("Columns:")
        print(preview.columns.tolist())

        print("\nPreview:")
        display(preview)
# Out:
# ================================================================================
# part4_model_compound_index.csv
# Exists: True
# Columns:
# ['record_id', 'perturbseqr_drug_id', 'name', 'match_name', 'smiles', 'broad_id', 'signature_name', 'moa', 'target']
#
# Preview:
#                 record_id     perturbseqr_drug_id                    name  \
# 0                 be-2254                 be-2254                 be-2254
# 1               dazmegrel               dazmegrel               dazmegrel
# 2               nobiletin               nobiletin               nobiletin
# 3                l-368899                l-368899                l-368899
# 4  betamethasone-valerate  betamethasone-valerate  betamethasone-valerate
#
#                match_name                                             smiles  \
# 0                 be-2254            Oc1ccc(CCNC[C@H]2CCc3ccccc3C2=O)cc1 |r|
# 1               dazmegrel                   Cc1c(Cn2ccnc2)c2ccccc2n1CCC(O)=O
# 2               nobiletin  COc1ccc(cc1OC)-c1cc(=O)c2c(OC)c(OC)c(OC)c(OC)c2o1
# 3                l-368899  Cc1ccccc1N1CCN(CC1)S(=O)(=O)C[C@]12CC[C@H](C[C...
# 4  betamethasone-valerate  CCCCC(=O)O[C@@]1([C@@H](C)C[C@H]2[C@@H]3CCC4=C...
#
#                  broad_id          signature_name  \
# 0  BRD-A24429032-003-03-2                 BE-2254
# 1  BRD-K20738689-001-01-2               dazmegrel
# 2  BRD-K06753942-001-14-5               nobiletin
# 3  BRD-K00004282-003-01-9                L-368899
# 4  BRD-K34032314-001-04-1  betamethasone-valerate
#
#                                moa             target
# 0   adrenergic receptor antagonist             ADRA1A
# 1   thromboxane synthase inhibitor             TBXAS1
# 2                    MEK inhibitor             MAP2K1
# 3     oxytocin receptor antagonist  AVPR1A|AVPR2|OXTR
# 4  glucocorticoid receptor agonist              NR3C1
# ================================================================================
# step3_multimodal_latent64_vectors.csv
# Exists: False
#
# ================================================================================
# part4_matched_consensus_signatures.csv.gz
# Exists: True
# Columns:
# ['signature_name', 'A1CF', 'A2M', 'A4GALT', 'A4GNT', 'AAAS', 'AACS', 'AADAC', 'AAGAB', 'AAK1', 'AAMDC', 'AAMP', 'AANAT', 'AAR2', 'AARS', 'AARSD1', 'AASDHPPT', 'AASS', 'AATF', 'AATK', 'ABAT', 'ABCA1', 'ABCA11P', 'ABCA12', 'ABCA2', 'ABCA3', 'ABCA4', 'ABCA5', 'ABCA6', 'ABCA7', 'ABCA8', 'ABCB1', 'ABCB11', 'ABCB4', 'ABCB6', 'ABCB7', 'ABCB8', 'ABCB9', 'ABCC1', 'ABCC10', 'ABCC2', 'ABCC3', 'ABCC4', 'ABCC5', 'ABCC6', 'ABCC8', 'ABCC9', 'ABCD1', 'ABCD2', 'ABCD3', 'ABCD4', 'ABCE1', 'ABCF1', 'ABCF2', 'ABCF3', 'ABCG1', 'ABCG2', 'ABCG4', 'ABCG5', 'ABHD10', 'ABHD11', 'ABHD14A', 'ABHD17A', 'ABHD17B', 'ABHD18', 'ABHD2', 'ABHD3', 'ABHD4', 'ABHD5', 'ABHD6', 'ABHD8', 'ABI1', 'ABI2', 'ABI3BP', 'ABITRAM', 'ABL1', 'ABL2', 'ABLIM1', 'ABLIM3', 'ABO', 'ABR', 'ABRAXAS2', 'ABT1', 'ABTB2', 'ACAA1', 'ACAA2', 'ACACA', 'ACACB', 'ACAD10', 'ACAD8', 'ACADL', 'ACADM', 'ACADS', 'ACADSB', 'ACADVL', 'ACAN', 'ACAP1', 'ACAP2', 'ACAT1', 'ACAT2', 'ACBD3', 'ACBD4', 'ACD', 'ACE', 'ACE2', 'ACHE', 'ACIN1', 'ACKR1', 'ACKR2', 'ACKR3', 'ACKR4', 'ACLY', 'ACO1', 'ACO2', 'ACOT11', 'ACOT13', 'ACOT7', 'ACOT8', 'ACOT9', 'ACOX1', 'ACOX2', 'ACOX3', 'ACOXL', 'ACP1', 'ACP2', 'ACP5', 'ACP6', 'ACPP', 'ACR', 'ACRV1', 'ACSBG1', 'ACSBG2', 'ACSF2', 'ACSL1', 'ACSL3', 'ACSL4', 'ACSL5', 'ACSL6', 'ACSM1', 'ACSM3', 'ACSM5', 'ACSS3', 'ACTA1', 'ACTA2', 'ACTB', 'ACTC1', 'ACTG2', 'ACTL6A', 'ACTL6B', 'ACTL7A', 'ACTL7B', 'ACTL8', 'ACTN1', 'ACTN2', 'ACTN3', 'ACTN4', 'ACTR10', 'ACTR1A', 'ACTR1B', 'ACTR2', 'ACTR3', 'ACTR3B', 'ACTR5', 'ACTR6', 'ACTR8', 'ACVR1', 'ACVR1B', 'ACVR2A', 'ACVR2B', 'ACVR2B-AS1', 'ACVRL1', 'ACYP1', 'ACYP2', 'ADA', 'ADA2', 'ADAM10', 'ADAM11', 'ADAM12', 'ADAM15', 'ADAM17', 'ADAM18', 'ADAM19', 'ADAM2', 'ADAM20', 'ADAM22', 'ADAM23', 'ADAM28', 'ADAM29', 'ADAM30', 'ADAM3A', 'ADAM5', 'ADAM7', 'ADAM8', 'ADAM9', 'ADAMDEC1', 'ADAMTS1', 'ADAMTS12', 'ADAMTS13', 'ADAMTS2', 'ADAMTS20', 'ADAMTS3', 'ADAMTS5', 'ADAMTS6', 'ADAMTS7', 'ADAMTS8', 'ADAMTS9', 'ADAMTSL2', 'ADAMTSL3', 'ADAMTSL4', 'ADAP1', 'ADAP2', 'ADAR', 'ADARB1', 'ADARB2', 'ADAT1', 'ADCK2', 'ADCY1', 'ADCY10', 'ADCY2', 'ADCY3', 'ADCY6', 'ADCY7', 'ADCY8', 'ADCY9', 'ADCYAP1', 'ADCYAP1R1', 'ADD1', 'ADD2', 'ADD3', 'ADGB', 'ADGRA2', 'ADGRA3', 'ADGRB1', 'ADGRB2', 'ADGRB3', 'ADGRE1', 'ADGRE2', 'ADGRE3', 'ADGRE5', 'ADGRF1', 'ADGRF5', 'ADGRG1', 'ADGRG2', 'ADGRG3', 'ADGRG6', 'ADGRL1', 'ADGRL2', 'ADGRL3', 'ADGRL4', 'ADGRV1', 'ADH1A', 'ADH1B', 'ADH1C', 'ADH5', 'ADH6', 'ADH7', 'ADI1', 'ADIPOQ', 'ADIPOR1', 'ADIPOR2', 'ADIRF', 'ADK', 'ADM', 'ADM2', 'ADNP', 'ADNP2', 'ADO', 'ADORA1', 'ADORA2B', 'ADORA3', 'ADPGK', 'ADPRH', 'ADPRM', 'ADRA1A', 'ADRA1B', 'ADRA1D', 'ADRA2A', 'ADRA2B', 'ADRA2C', 'ADRB1', 'ADRB2', 'ADRB3', 'ADRM1', 'ADSL', 'ADSS', 'ADTRP', 'AEBP1', 'AEN', 'AFAP1', 'AFDN', 'AFDN-DT', 'AFF1', 'AFF2', 'AFF3', 'AFF4', 'AFG3L2', 'AFM', 'AFP', 'AFTPH', 'AGA', 'AGAP1', 'AGAP2', 'AGBL2', 'AGBL3', 'AGBL5', 'AGER', 'AGFG1', 'AGFG2', 'AGGF1', 'AGK', 'AGL', 'AGMAT', 'AGO1', 'AGO2', 'AGO3', 'AGO4', 'AGPAT1', 'AGPAT2', 'AGPAT3', 'AGPAT4', 'AGPAT5', 'AGPS', 'AGR2', 'AGRN', 'AGRP', 'AGT', 'AGTPBP1', 'AGTR1', 'AGTR2', 'AGXT', 'AHCTF1', 'AHCY', 'AHCYL1', 'AHCYL2', 'AHDC1', 'AHI1', 'AHNAK', 'AHNAK2', 'AHR', 'AHSA1', 'AHSG', 'AHSP', 'AICDA', 'AIDA', 'AIF1', 'AIFM1', 'AIM2', 'AIMP1', 'AIMP2', 'AIP', 'AIPL1', 'AIRE', 'AJAP1', 'AK1', 'AK2', 'AK4', 'AK5', 'AKAP1', 'AKAP10', 'AKAP11', 'AKAP12', 'AKAP13', 'AKAP17A', 'AKAP3', 'AKAP4', 'AKAP5', 'AKAP6', 'AKAP7', 'AKAP8', 'AKAP8L', 'AKAP9', 'AKIP1', 'AKIRIN1', 'AKR1A1', 'AKR1B1', 'AKR1B10', 'AKR1C1', 'AKR1C2', 'AKR1C3', 'AKR1C4', 'AKR1D1', 'AKR7A2', 'AKR7A3', 'AKT1', 'AKT2', 'AKT3', 'AKTIP', 'ALAD', 'ALAS1', 'ALAS2', 'ALB', 'ALCAM', 'ALDH18A1', 'ALDH1A1', 'ALDH1A2', 'ALDH1A3', 'ALDH1B1', 'ALDH1L1', 'ALDH2', 'ALDH3A1', 'ALDH3A2', 'ALDH3B1', 'ALDH3B2', 'ALDH4A1', 'ALDH5A1', 'ALDH6A1', 'ALDH7A1', 'ALDH8A1', 'ALDH9A1', 'ALDOA', 'ALDOB', 'ALDOC', 'ALG12', 'ALG13', 'ALG3', 'ALG5', 'ALG6', 'ALG8', 'ALK', 'ALKBH1', 'ALKBH4', 'ALLC', 'ALMS1', 'ALOX12', 'ALOX12B', 'ALOX15', 'ALOX15B', 'ALOX5', 'ALOX5AP', 'ALOXE3', 'ALPG', 'ALPI', 'ALP ...
#
# Preview:
#   signature_name      A1CF       A2M    A4GALT     A4GNT      AAAS      AACS  \
# 0       afatinib  0.001353 -0.002113 -0.000360  0.000507 -0.000123  0.000799
# 1      erlotinib  0.000755 -0.000268 -0.000690  0.000107  0.000050 -0.000775
# 2      neratinib  0.000463 -0.003915 -0.000118  0.000174 -0.000900  0.000787
# 3      lapatinib -0.000138  0.000255  0.000192 -0.000241  0.000348  0.000737
# 4      pazopanib -0.000276  0.000854 -0.000363 -0.000167 -0.000008 -0.001390
#
#       AADAC     AAGAB      AAK1  ...    ZSWIM8      ZW10    ZWILCH     ZWINT  \
# 0 -0.001517  0.000513  0.000318  ... -0.000855  0.000328  0.000380  0.000249
# 1 -0.000117  0.000221  0.000201  ... -0.000507 -0.000284 -0.000464  0.000107
# 2 -0.001803  0.000287  0.000227  ... -0.001338 -0.002059 -0.000744 -0.001082
# 3  0.000374  0.000118  0.000201  ... -0.000304  0.000492  0.000516  0.000622
# 4 -0.000128  0.000292  0.000236  ... -0.000789 -0.000261 -0.000478  0.000567
#
#        ZXDB      ZXDC       ZYX     ZZEF1      ZZZ3  match_name
# 0 -0.000288 -0.000166 -0.001050 -0.000466  0.000288    afatinib
# 1 -0.000133  0.001099 -0.000782  0.000303  0.000757   erlotinib
# 2 -0.000022  0.000142 -0.000774 -0.000808  0.000365   neratinib
# 3 -0.000028  0.000251 -0.000321 -0.000546  0.000612   lapatinib
# 4 -0.000053 -0.000186 -0.000057 -0.001396  0.001257   pazopanib
#
# [5 rows x 12329 columns]

# %%
compound_index = pd.read_csv("part4_model_compound_index.csv")
compound_embeddings = pd.read_csv(
    "morgan_autoencoder_latent64_vectors.csv"
)

print("Compound index shape:", compound_index.shape)
print("Compound embeddings shape:", compound_embeddings.shape)

print("\nCompound index columns:")
print(compound_index.columns.tolist())

print("\nEmbedding columns:")
print(compound_embeddings.columns.tolist())

display(compound_index.head())
display(compound_embeddings.head())
# Out:
# Compound index shape: (3131, 9)
# Compound embeddings shape: (28574, 74)
#
# Compound index columns:
# ['record_id', 'perturbseqr_drug_id', 'name', 'match_name', 'smiles', 'broad_id', 'signature_name', 'moa', 'target']
#
# Embedding columns:
# ['Unnamed: 0', 'pert_name', 'target', 'moa', 'canonical_smiles', 'inchi_key', 'compound_aliases', 'sig_count', 'valid_smiles', 'split', 'latent_1', 'latent_2', 'latent_3', 'latent_4', 'latent_5', 'latent_6', 'latent_7', 'latent_8', 'latent_9', 'latent_10', 'latent_11', 'latent_12', 'latent_13', 'latent_14', 'latent_15', 'latent_16', 'latent_17', 'latent_18', 'latent_19', 'latent_20', 'latent_21', 'latent_22', 'latent_23', 'latent_24', 'latent_25', 'latent_26', 'latent_27', 'latent_28', 'latent_29', 'latent_30', 'latent_31', 'latent_32', 'latent_33', 'latent_34', 'latent_35', 'latent_36', 'latent_37', 'latent_38', 'latent_39', 'latent_40', 'latent_41', 'latent_42', 'latent_43', 'latent_44', 'latent_45', 'latent_46', 'latent_47', 'latent_48', 'latent_49', 'latent_50', 'latent_51', 'latent_52', 'latent_53', 'latent_54', 'latent_55', 'latent_56', 'latent_57', 'latent_58', 'latent_59', 'latent_60', 'latent_61', 'latent_62', 'latent_63', 'latent_64']
#                 record_id     perturbseqr_drug_id                    name  \
# 0                 be-2254                 be-2254                 be-2254
# 1               dazmegrel               dazmegrel               dazmegrel
# 2               nobiletin               nobiletin               nobiletin
# 3                l-368899                l-368899                l-368899
# 4  betamethasone-valerate  betamethasone-valerate  betamethasone-valerate
#
#                match_name                                             smiles  \
# 0                 be-2254            Oc1ccc(CCNC[C@H]2CCc3ccccc3C2=O)cc1 |r|
# 1               dazmegrel                   Cc1c(Cn2ccnc2)c2ccccc2n1CCC(O)=O
# 2               nobiletin  COc1ccc(cc1OC)-c1cc(=O)c2c(OC)c(OC)c(OC)c(OC)c2o1
# 3                l-368899  Cc1ccccc1N1CCN(CC1)S(=O)(=O)C[C@]12CC[C@H](C[C...
# 4  betamethasone-valerate  CCCCC(=O)O[C@@]1([C@@H](C)C[C@H]2[C@@H]3CCC4=C...
#
#                  broad_id          signature_name  \
# 0  BRD-A24429032-003-03-2                 BE-2254
# 1  BRD-K20738689-001-01-2               dazmegrel
# 2  BRD-K06753942-001-14-5               nobiletin
# 3  BRD-K00004282-003-01-9                L-368899
# 4  BRD-K34032314-001-04-1  betamethasone-valerate
#
#                                moa             target
# 0   adrenergic receptor antagonist             ADRA1A
# 1   thromboxane synthase inhibitor             TBXAS1
# 2                    MEK inhibitor             MAP2K1
# 3     oxytocin receptor antagonist  AVPR1A|AVPR2|OXTR
# 4  glucocorticoid receptor agonist              NR3C1
#       Unnamed: 0     pert_name                             target  \
# 0  BRD-K60230970        MG-132                              PSMB1
# 1  BRD-K50691590    bortezomib                PSMB2, PSMB5, PSMB1
# 2  BRD-K81418486    vorinostat  HDAC8, HDAC2, HDAC3, HDAC6, HDAC1
# 3  BRD-K49865102    PD-0325901                             MAP2K1
# 4  BRD-K21680192  mitoxantrone                              TOP2A
#
#                                                  moa  \
# 0                               Proteasome inhibitor
# 1       Proteasome inhibitor, NFKB pathway inhibitor
# 2                                     HDAC inhibitor
# 3  MEK inhibitor, Protein kinase inhibitor, MAP k...
# 4                            Topoisomerase inhibitor
#
#                                     canonical_smiles  \
# 0  CC(C)C[C@H](NC(=O)[C@H](CC(C)C)NC(=O)[C@H](CC(...
# 1  CC(C)C[C@@H](NC(=O)[C@@H](Cc1ccccc1)NC(=O)C1=C...
# 2                        ONC(=O)CCCCCCC(=O)Nc1ccccc1
# 3     OC[C@@H](O)CONC(=O)c1ccc(F)c(F)c1Nc1ccc(I)cc1F
# 4  OCCNCCNc1ccc(NCCNCCO)c2C(=O)c3c(O)ccc(O)c3C(=O...
#
#                      inchi_key compound_aliases  sig_count  valid_smiles  \
# 0  TZYWCYJVHRLUCT-VABKMULXSA-N                -       8257          True
# 1  RFGAQTOFZHCFHG-NVXWUHKLSA-N                -       6776          True
# 2  WAEXFXRVDQXREF-UHFFFAOYSA-N                -       3244          True
# 3  SUDAHWBOROXANE-SECBINFHSA-N                -       1796          True
# 4  KKZJGLLVHKMTCM-UHFFFAOYSA-N                -       1740          True
#
#    split  ...  latent_55  latent_56  latent_57  latent_58  latent_59  \
# 0  train  ... -19.820385  -7.112452   4.440944  -9.822842  -9.839583
# 1  train  ... -13.786310  -4.547864   3.391103  -5.140367  -4.442291
# 2  train  ... -16.452637  -9.933352  11.547052  -3.825564  -8.993432
# 3   test  ... -20.394136  -7.541328   7.494266  -9.395048  -2.053769
# 4  train  ... -20.724556  -4.973541   5.448934  -4.093792  -3.385640
#
#    latent_60  latent_61  latent_62  latent_63  latent_64
# 0  -9.229491   1.932333  -5.603589  -3.211800  -7.677505
# 1  -8.648558   2.156909  -9.736707   0.458286  -4.402381
# 2  -8.666147  -5.651190  -5.757975   2.577652  -6.742382
# 3 -10.210070   0.245343  -6.107342  -1.402413  -7.992792
# 4  -4.707429  -1.505551  -4.358154   3.886660  -6.215302
#
# [5 rows x 74 columns]

# %%
from pathlib import Path

step3_folder = Path("step3_multimodal")

print("Exists:", step3_folder.exists())
print("Is directory:", step3_folder.is_dir())

if step3_folder.is_dir():
    for path in step3_folder.iterdir():
        print(path.name)
# Out:
# Exists: True
# Is directory: True
# step3_model_table_summary_by_match_method.csv
# step3_bowtie_row_errors_latent256_final_with_source_normalized.csv
# step3_bowtie_error_summary_by_source.csv
# step3_final256_highconf_most_predictable_source_normalized_n20.csv
# step3_least_predictable_compounds_n5_first_pass.csv
# step3_bowtie_row_metadata_first_pass.csv
# step3_multimodal_model_table_matched_improved.csv
# step3_model_table_summary.txt
# step3_final256_error_summary_by_source_improved.csv
# step3_signature_to_compound_matched_table.csv
# step3_final256_high_confidence_predictability_interpretation.txt
# step3_final256_least_predictable_compounds_n20.csv
# step3_bowtie_feature_names_first_pass.csv
# step3_bowtie_arrays_first_pass_summary.txt
# step3_compound_predictability_first_pass_summary.txt
# step3_compound_predictability_first_pass.csv
# step3_final256_error_summary_by_profile_count_bin.csv
# step3_model_table_summary_by_source.csv
# step3_final256_least_predictable_compounds_n5.csv
# step3_final256_most_predictable_compounds_n5.csv
# step3_final256_bowtie_error_summary_by_source.csv
# step3_final256_highconf_most_predictable_raw_n20.csv
# step3_compound_predictability_latent256_final.csv
# step3_final256_highconf_most_predictable_raw_n100.csv
# step3_compound_predictability_latent256_final_scores.csv
# step3_compound_predictability_latent256_final_with_source_normalized.csv
# step3_compound_predictability_latent256_final_summary.txt
# step3_final256_predictability_scores_report_table.csv
# step3_final256_highconf_least_predictable_raw_n20.csv
# step3_final256_highconf_least_predictable_source_normalized_n20.csv
# step3_bowtie_row_errors_latent256_final.csv
# step4_source_normalized_predictability_filter_sweep_predictions.csv
# step3_final256_profile_count_confound_summary.csv
# step3_final256_highconf_least_predictable_raw_n100.csv
# step3_top_predictable_compounds_n5_first_pass.csv
# step3_bowtie_row_errors_first_pass.csv
# step3_signature_to_compound_match_method_counts.csv
# step3_final256_profile_count_correlations.csv
# step3_signature_to_compound_match_summary.txt
# step3_unmatched_signature_compound_examples.csv
# step3_final256_least_predictable_source_normalized_n20.csv
# step3_bowtie_arrays_first_pass.npz
# step3_final256_most_predictable_compounds_n20.csv
# step3_signature_to_compound_matched_table_improved.csv
# step4_predictability_regression_test_predictions.csv
# step3_signature_to_compound_match_summary_improved.txt
# step3_final256_most_predictable_source_normalized_n20.csv

# %%
import nbformat

notebook = nbformat.read("part4_predicting.ipynb", as_version=4)

search_terms = [
    "r2",
    "predictability",
    "reconstruction_error",
    "variance",
    "compound_scores"
]

for i, cell in enumerate(notebook.cells):
    if cell.cell_type == "code":
        source_lower = cell.source.lower()

        if any(term in source_lower for term in search_terms):
            print("\n" + "=" * 80)
            print(f"CELL {i}")
            print(cell.source[:3000])

# %%
import pandas as pd
from pathlib import Path

score_files = [
    "step3_multimodal/step3_compound_predictability_latent256_final_scores.csv",
    "step3_multimodal/step3_compound_predictability_latent256_final_with_source_normalized.csv",
    "step3_multimodal/step3_final256_high_confidence_predictability_scores.csv",
]

for filename in score_files:
    print("\n" + "=" * 100)
    print(filename)

    df = pd.read_csv(filename)

    print("Shape:", df.shape)
    print("Columns:")
    print(df.columns.tolist())

    display(df.head())
# Out:
# ====================================================================================================
# step3_multimodal/step3_compound_predictability_latent256_final_scores.csv
# Shape: (6605, 30)
# Columns:
# ['compound_embedding_row_index', 'compound_name', 'n_profiles', 'mean_total_error', 'variance_total_error', 'std_total_error', 'median_total_error', 'mean_signature_error', 'variance_signature_error', 'std_signature_error', 'mean_compound_error', 'variance_compound_error', 'mean_numeric_error', 'mean_categorical_error', 'mean_signature_reconstruction_loss', 'mean_compound_reconstruction_bce', 'mean_signature_sign_accuracy', 'mean_compound_bitwise_accuracy', 'error_percentile', 'predictability_score', 'mean_source_normalized_error_z', 'variance_source_normalized_error_z', 'std_source_normalized_error_z', 'median_source_normalized_error_z', 'n_sources', 'source_normalized_error_percentile', 'source_normalized_predictability_score', 'profile_count_bin', 'raw_error_inverted_score', 'source_normalized_inverted_score']
#    compound_embedding_row_index  \
# 0                          1911
# 1                          2536
# 2                          3116
# 3                           761
# 4                          5185
#
#                                        compound_name  n_profiles  \
# 0  (1R,9S,12S,13R,14S,17R,18E,21S,23S,24R,25S,27R...           2
# 1  Emate; [(8R,9S,13S,14S)-13-methyl-17-oxo-7,8,9...           2
# 2  5-[(5-chloro-1H-pyrrolo[2,3-b]pyridin-3-yl)met...           1
# 3  Halobetasol Propionate; [(6S,8S,9R,10S,11S,13S...           4
# 4  Doxorubicin (hydrochloride); Doxorubicin Hydro...         280
#
#    mean_total_error  variance_total_error  std_total_error  \
# 0          0.030199              0.000001         0.001093
# 1          0.032967              0.000018         0.004273
# 2          0.033087              0.000000         0.000000
# 3          0.034146              0.000026         0.005115
# 4          0.035060              0.000103         0.010144
#
#    median_total_error  mean_signature_error  variance_signature_error  \
# 0            0.030199              0.015241                  0.000002
# 1            0.032967              0.017886                  0.000046
# 2            0.033087              0.018455                  0.000000
# 3            0.033608              0.016936                  0.000017
# 4            0.033378              0.026343                  0.000096
#
#    std_signature_error  ...  mean_source_normalized_error_z  \
# 0             0.001327  ...                       -1.281762
# 1             0.006774  ...                       -1.243400
# 2             0.000000  ...                       -1.241747
# 3             0.004152  ...                       -1.227075
# 4             0.009821  ...                       -0.719053
#
#    variance_source_normalized_error_z  std_source_normalized_error_z  \
# 0                            0.000229                       0.015144
# 1                            0.003506                       0.059213
# 2                            0.000000                       0.000000
# 3                            0.005024                       0.070877
# 4                            0.713194                       0.844508
#
#    median_source_normalized_error_z  n_sources  \
# 0                         -1.281762          1
# 1                         -1.243400          1
# 2                         -1.241747          1
# 3                         -1.234528          1
# 4                         -0.859132          1
#
#    source_normalized_error_percentile  source_normalized_predictability_score  \
# 0                            0.000151                                0.999849
# 1                            0.000303                                0.999697
# 2                            0.000454                                0.999546
# 3                            0.000606                                0.999394
# 4                            0.025284                                0.974716
#
#    profile_count_bin  raw_error_inverted_score  \
# 0                2-4                       1.0
# 1                2-4                       1.0
# 2                  1                       1.0
# 3                2-4                       1.0
# 4               100+                       1.0
#
#    source_normalized_inverted_score
# 0                          1.000000
# 1                          1.000000
# 2                          1.000000
# 3                          1.000000
# 4                          0.969265
#
# [5 rows x 30 columns]
# ====================================================================================================
# step3_multimodal/step3_compound_predictability_latent256_final_with_source_normalized.csv
# Shape: (6605, 28)
# Columns:
# ['compound_embedding_row_index', 'compound_name', 'n_profiles', 'mean_total_error', 'variance_total_error', 'std_total_error', 'median_total_error', 'mean_signature_error', 'variance_signature_error', 'std_signature_error', 'mean_compound_error', 'variance_compound_error', 'mean_numeric_error', 'mean_categorical_error', 'mean_signature_reconstruction_loss', 'mean_compound_reconstruction_bce', 'mean_signature_sign_accuracy', 'mean_compound_bitwise_accuracy', 'error_percentile', 'predictability_score', 'mean_source_normalized_error_z', 'variance_source_normalized_error_z', 'std_source_normalized_error_z', 'median_source_normalized_error_z', 'n_sources', 'source_normalized_error_percentile', 'source_normalized_predictability_score', 'profile_count_bin']
#    compound_embedding_row_index  \
# 0                          1911
# 1                          2536
# 2                          3116
# 3                           761
# 4                          5185
#
#                                        compound_name  n_profiles  \
# 0  (1R,9S,12S,13R,14S,17R,18E,21S,23S,24R,25S,27R...           2
# 1  Emate; [(8R,9S,13S,14S)-13-methyl-17-oxo-7,8,9...           2
# 2  5-[(5-chloro-1H-pyrrolo[2,3-b]pyridin-3-yl)met...           1
# 3  Halobetasol Propionate; [(6S,8S,9R,10S,11S,13S...           4
# 4  Doxorubicin (hydrochloride); Doxorubicin Hydro...         280
#
#    mean_total_error  variance_total_error  std_total_error  \
# 0          0.030199              0.000001         0.001093
# 1          0.032967              0.000018         0.004273
# 2          0.033087              0.000000         0.000000
# 3          0.034146              0.000026         0.005115
# 4          0.035060              0.000103         0.010144
#
#    median_total_error  mean_signature_error  variance_signature_error  \
# 0            0.030199              0.015241                  0.000002
# 1            0.032967              0.017886                  0.000046
# 2            0.033087              0.018455                  0.000000
# 3            0.033608              0.016936                  0.000017
# 4            0.033378              0.026343                  0.000096
#
#    std_signature_error  ...  error_percentile  predictability_score  \
# 0             0.001327  ...          0.000151              0.999849
# 1             0.006774  ...          0.000303              0.999697
# 2             0.000000  ...          0.000454              0.999546
# 3             0.004152  ...          0.000606              0.999394
# 4             0.009821  ...          0.000757              0.999243
#
#    mean_source_normalized_error_z  variance_source_normalized_error_z  \
# 0                       -1.281762                            0.000229
# 1                       -1.243400                            0.003506
# 2                       -1.241747                            0.000000
# 3                       -1.227075                            0.005024
# 4                       -0.719053                            0.713194
#
#    std_source_normalized_error_z  median_source_normalized_error_z  n_sources  \
# 0                       0.015144                         -1.281762          1
# 1                       0.059213                         -1.243400          1
# 2                       0.000000                         -1.241747          1
# 3                       0.070877                         -1.234528          1
# 4                       0.844508                         -0.859132          1
#
#    source_normalized_error_percentile  source_normalized_predictability_score  \
# 0                            0.000151                                0.999849
# 1                            0.000303                                0.999697
# 2                            0.000454                                0.999546
# 3                            0.000606                                0.999394
# 4                            0.025284                                0.974716
#
#    profile_count_bin
# 0                2-4
# 1                2-4
# 2                  1
# 3                2-4
# 4               100+
#
# [5 rows x 28 columns]
# ====================================================================================================
# step3_multimodal/step3_final256_high_confidence_predictability_scores.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 14
#      10 for filename in score_files:
#      11     print("\n" + "=" * 100)
#      12     print(filename)
#      13
# ---> 14     df = pd.read_csv(filename)
#      15
#      16     print("Shape:", df.shape)
#      17     print("Columns:")
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/io/common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'step3_multimodal/step3_final256_high_confidence_predictability_scores.csv'

# %%
predictability = pd.read_csv(
    "step3_multimodal/"
    "step3_compound_predictability_latent256_final_with_source_normalized.csv"
)

print("Predictability identifiers:")
for col in predictability.columns:
    if any(term in col.lower() for term in [
        "pert", "compound", "drug", "smiles", "inchi", "name", "id"
    ]):
        print(col)

print("\nEmbedding identifiers:")
for col in compound_embeddings.columns:
    if any(term in col.lower() for term in [
        "pert", "compound", "drug", "smiles", "inchi", "name", "id"
    ]):
        print(col)
# Out:
# Predictability identifiers:
# compound_embedding_row_index
# compound_name
# mean_compound_error
# variance_compound_error
# mean_compound_reconstruction_bce
# mean_compound_bitwise_accuracy
#
# Embedding identifiers:
# Unnamed: 0
# pert_name
# canonical_smiles
# inchi_key
# compound_aliases
# valid_smiles

# %%
from pathlib import Path
import numpy as np
import pandas as pd
from IPython.display import display

# Notebook opened from
cwd = Path.cwd()

if (cwd / "step3_multimodal").exists():
    DATA_DIR = cwd
elif (cwd / "data" / "step3_multimodal").exists():
    DATA_DIR = cwd / "data"
else:
    raise FileNotFoundError(
        "Could not find the data/step3_multimodal folder."
    )

PROJECT_ROOT = DATA_DIR.parent

SCORE_PATH = (
    DATA_DIR
    / "step3_multimodal"
    / "step3_compound_predictability_latent256_final_with_source_normalized.csv"
)

EMBEDDING_PATH = (
    DATA_DIR
    / "step1_embeddings"
    / "step1_drug_embeddings_128.npy"
)

OLD_METRICS_PATH = (
    PROJECT_ROOT
    / "models"
    / "step4_source_normalized_predictability_filter_sweep_metrics.csv"
)

print("Data directory:", DATA_DIR)
print("Project root:", PROJECT_ROOT)
print("Score file exists:", SCORE_PATH.exists())
print("128D embedding file exists:", EMBEDDING_PATH.exists())
print("Previous metrics exist:", OLD_METRICS_PATH.exists())

assert SCORE_PATH.exists(), f"Missing: {SCORE_PATH}"
assert EMBEDDING_PATH.exists(), f"Missing: {EMBEDDING_PATH}"
# Out:
# Data directory: /Users/mell/predicting-predictability/data
# Project root: /Users/mell/predicting-predictability
# Score file exists: True
# 128D embedding file exists: True
# Previous metrics exist: True

# %%
target_col = "source_normalized_inverted_score"

SCORE_PATH = (
    DATA_DIR
    / "step3_multimodal"
    / "step3_compound_predictability_latent256_final_scores.csv"
)

scores = pd.read_csv(SCORE_PATH)

print("Loaded:", SCORE_PATH)
print("Shape:", scores.shape)
print("Target exists:", target_col in scores.columns)

assert target_col in scores.columns, (
    f"{target_col} is missing. Available score columns: "
    f"{[col for col in scores.columns if 'score' in col.lower()]}"
)

required_columns = [
    "compound_embedding_row_index",
    "compound_name",
    "n_profiles",
    target_col,
]

compound_table = (
    scores
    .dropna(subset=required_columns)
    .copy()
)

compound_table["compound_embedding_row_index"] = (
    compound_table["compound_embedding_row_index"]
    .astype(int)
)

compound_table["n_profiles"] = (
    compound_table["n_profiles"]
    .astype(int)
)

compound_table = compound_table.reset_index(drop=True)

print("Original score rows:", len(scores))
print("Usable compound rows:", len(compound_table))
print(
    "Unique embedding indices:",
    compound_table["compound_embedding_row_index"].nunique()
)
print(
    "Duplicate embedding indices:",
    compound_table["compound_embedding_row_index"]
    .duplicated()
    .sum()
)

display(
    compound_table[
        [
            "compound_embedding_row_index",
            "compound_name",
            "n_profiles",
            target_col,
        ]
    ].head()
)

display(
    compound_table[
        ["n_profiles", target_col]
    ].describe()
)
# Out:
# Loaded: /Users/mell/predicting-predictability/data/step3_multimodal/step3_compound_predictability_latent256_final_scores.csv
# Shape: (6605, 30)
# Target exists: True
# Original score rows: 6605
# Usable compound rows: 6605
# Unique embedding indices: 6605
# Duplicate embedding indices: 0
#    compound_embedding_row_index  \
# 0                          1911
# 1                          2536
# 2                          3116
# 3                           761
# 4                          5185
#
#                                        compound_name  n_profiles  \
# 0  (1R,9S,12S,13R,14S,17R,18E,21S,23S,24R,25S,27R...           2
# 1  Emate; [(8R,9S,13S,14S)-13-methyl-17-oxo-7,8,9...           2
# 2  5-[(5-chloro-1H-pyrrolo[2,3-b]pyridin-3-yl)met...           1
# 3  Halobetasol Propionate; [(6S,8S,9R,10S,11S,13S...           4
# 4  Doxorubicin (hydrochloride); Doxorubicin Hydro...         280
#
#    source_normalized_inverted_score
# 0                          1.000000
# 1                          1.000000
# 2                          1.000000
# 3                          1.000000
# 4                          0.969265
#         n_profiles  source_normalized_inverted_score
# count  6605.000000                       6605.000000
# mean     17.104315                          0.667898
# std      70.548126                          0.212247
# min       1.000000                          0.000000
# 25%       2.000000                          0.542136
# 50%       4.000000                          0.709367
# 75%       8.000000                          0.829027
# max    3036.000000                          1.000000

# %%
import numpy as np

EMBEDDING_PATH = (
    DATA_DIR
    / "step1_embeddings"
    / "step1_drug_embeddings_128.npy"
)

print("Embedding file:", EMBEDDING_PATH)
print("Exists:", EMBEDDING_PATH.exists())

# Avoid loading all 3.7 million
all_embeddings = np.load(
    EMBEDDING_PATH,
    mmap_mode="r"
)

print("Full embedding array shape:", all_embeddings.shape)
print("Embedding dtype:", all_embeddings.dtype)

if all_embeddings.ndim != 2:
    raise ValueError(
        f"Expected a 2D array, got shape {all_embeddings.shape}"
    )

if all_embeddings.shape[1] != 128:
    raise ValueError(
        f"Expected 128 latent dimensions, got {all_embeddings.shape[1]}"
    )

embedding_indices = (
    compound_table["compound_embedding_row_index"]
    .to_numpy(dtype=int)
)

print("Minimum requested index:", embedding_indices.min())
print("Maximum requested index:", embedding_indices.max())
print("Number of available embedding rows:", all_embeddings.shape[0])

if embedding_indices.min() < 0:
    raise IndexError("Negative embedding index detected.")

if embedding_indices.max() >= all_embeddings.shape[0]:
    raise IndexError(
        "At least one embedding index is outside the array."
    )

# Extract only the 6,605 profiled compounds
X_all = np.asarray(
    all_embeddings[embedding_indices],
    dtype=np.float32
)

y_all = compound_table[target_col].to_numpy(
    dtype=np.float32
)

print("\nX_all shape:", X_all.shape)
print("y_all shape:", y_all.shape)
print("All X values finite:", np.isfinite(X_all).all())
print("All y values finite:", np.isfinite(y_all).all())

assert X_all.shape == (len(compound_table), 128)
assert y_all.shape == (len(compound_table),)
assert np.isfinite(X_all).all()
assert np.isfinite(y_all).all()
# Out:
# Embedding file: /Users/mell/predicting-predictability/data/step1_embeddings/step1_drug_embeddings_128.npy
# Exists: True
# Full embedding array shape: (3765890, 128)
# Embedding dtype: float32
# Minimum requested index: 0
# Maximum requested index: 2325590
# Number of available embedding rows: 3765890
#
# X_all shape: (6605, 128)
# y_all shape: (6605,)
# All X values finite: True
# All y values finite: True

# %%
thresholds = [2, 5, 10, 20, 50, 100]

threshold_rows = []

for threshold in thresholds:
    subset = compound_table[
        compound_table["n_profiles"] >= threshold
    ]

    threshold_rows.append({
        "minimum_profiles": threshold,
        "n_compounds": len(subset),
        "mean_n_profiles": subset["n_profiles"].mean(),
        "median_n_profiles": subset["n_profiles"].median(),
        "mean_target": subset[target_col].mean(),
        "median_target": subset[target_col].median(),
        "target_std": subset[target_col].std(),
        "target_min": subset[target_col].min(),
        "target_max": subset[target_col].max(),
    })

threshold_summary = pd.DataFrame(threshold_rows)

display(threshold_summary)

print(
    "Compounds with at least 100 profiles:",
    int((compound_table["n_profiles"] >= 100).sum())
)
# Out:
#    minimum_profiles  n_compounds  mean_n_profiles  median_n_profiles  \
# 0                 2         5271        21.180042                4.0
# 1                 5         2624        39.533155               11.0
# 2                10         1463        65.760766               23.0
# 3                20          801       109.344569               74.0
# 4                50          478       162.041841              140.0
# 5               100          349       196.349570              143.0
#
#    mean_target  median_target  target_std  target_min  target_max
# 0     0.696587       0.734315    0.192706    0.000000         1.0
# 1     0.729087       0.761047    0.158501    0.000000         1.0
# 2     0.778751       0.801525    0.123387    0.146735         1.0
# 3     0.826764       0.836058    0.089164    0.300781         1.0
# 4     0.852733       0.862818    0.075286    0.591450         1.0
# 5     0.848049       0.859776    0.079902    0.591450         1.0
# Compounds with at least 100 profiles: 349

# %%
OLD_METRICS_PATH = (
    PROJECT_ROOT
    / "models"
    / "step4_source_normalized_predictability_filter_sweep_metrics.csv"
)

old_metrics = pd.read_csv(OLD_METRICS_PATH)

print("Previous Step 4 metrics shape:", old_metrics.shape)
print("Columns:")
print(old_metrics.columns.tolist())

display(old_metrics)
# Out:
# Previous Step 4 metrics shape: (12, 12)
# Columns:
# ['target', 'target_label', 'model', 'min_profiles', 'n_total', 'n_train', 'n_test', 'n_features', 'r2', 'mae', 'rmse', 'spearman']
#                               target                            target_label  \
# 0   source_normalized_inverted_score  Source-normalized predictability score
# 1   source_normalized_inverted_score  Source-normalized predictability score
# 2   source_normalized_inverted_score  Source-normalized predictability score
# 3   source_normalized_inverted_score  Source-normalized predictability score
# 4   source_normalized_inverted_score  Source-normalized predictability score
# 5   source_normalized_inverted_score  Source-normalized predictability score
# 6   source_normalized_inverted_score  Source-normalized predictability score
# 7   source_normalized_inverted_score  Source-normalized predictability score
# 8   source_normalized_inverted_score  Source-normalized predictability score
# 9   source_normalized_inverted_score  Source-normalized predictability score
# 10  source_normalized_inverted_score  Source-normalized predictability score
# 11  source_normalized_inverted_score  Source-normalized predictability score
#
#                      model  min_profiles  n_total  n_train  n_test  \
# 0              extra_trees           100      349      279      70
# 1            random_forest           100      349      279      70
# 2   hist_gradient_boosting           100      349      279      70
# 3                    ridge           100      349      279      70
# 4            random_forest             5     2624     2099     525
# 5              extra_trees             5     2624     2099     525
# 6   hist_gradient_boosting             5     2624     2099     525
# 7            random_forest            20      801      640     161
# 8              extra_trees            20      801      640     161
# 9   hist_gradient_boosting            20      801      640     161
# 10                   ridge            20      801      640     161
# 11                   ridge             5     2624     2099     525
#
#     n_features        r2       mae      rmse  spearman
# 0          130  0.305456  0.054045  0.070487  0.598705
# 1          130  0.277051  0.055355  0.071914  0.536593
# 2          130  0.273663  0.058345  0.072082  0.522771
# 3          130 -0.156155  0.070264  0.090943  0.410725
# 4          130  0.152284  0.109316  0.142631  0.409388
# 5          130  0.153523  0.108736  0.142527  0.406186
# 6          130  0.154524  0.107956  0.142443  0.404982
# 7          130  0.141118  0.062921  0.083153  0.397126
# 8          130  0.153676  0.063037  0.082543  0.393112
# 9          130  0.127261  0.063127  0.083821  0.372066
# 10         130  0.032433  0.069968  0.088258  0.348906
# 11         130  0.024511  0.116579  0.153003  0.283965

# %%
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import RepeatedKFold
from scipy.stats import spearmanr

RANDOM_STATE = 42

# Thresholds
evaluation_thresholds = [
    5,
    10,
    20,
    25,
    50,
    75,
    100,
]

cv = RepeatedKFold(
    n_splits=5,
    n_repeats=3,
    random_state=RANDOM_STATE,
)

cv_rows = []

for threshold in evaluation_thresholds:
    mask = (
        compound_table["n_profiles"] >= threshold
    ).to_numpy()

    X = X_all[mask]
    y = y_all[mask]

    print(
        f"\nThreshold >= {threshold}: "
        f"{len(y)} compounds"
    )

    for fold_number, (train_idx, test_idx) in enumerate(
        cv.split(X),
        start=1,
    ):
        model = ExtraTreesRegressor(
            n_estimators=300,
            random_state=RANDOM_STATE + fold_number,
            n_jobs=-1,
        )

        model.fit(
            X[train_idx],
            y[train_idx],
        )

        predictions = model.predict(
            X[test_idx]
        )

        r2 = r2_score(
            y[test_idx],
            predictions,
        )

        mae = mean_absolute_error(
            y[test_idx],
            predictions,
        )

        spearman = spearmanr(
            y[test_idx],
            predictions,
        ).correlation

        if np.isnan(spearman):
            spearman = 0.0

        cv_rows.append({
            "minimum_profiles": threshold,
            "n_compounds": len(y),
            "fold": fold_number,
            "r2": r2,
            "mae": mae,
            "spearman": spearman,
        })

extra_trees_cv_results = pd.DataFrame(cv_rows)

print("\nFinished threshold sweep.")
display(extra_trees_cv_results.head())
# Out:
# Threshold >= 5: 2624 compounds
#
# Threshold >= 10: 1463 compounds
#
# Threshold >= 20: 801 compounds
#
# Threshold >= 25: 700 compounds
#
# Threshold >= 50: 478 compounds
#
# Threshold >= 75: 398 compounds
#
# Threshold >= 100: 349 compounds
#
# Finished threshold sweep.
#    minimum_profiles  n_compounds  fold        r2       mae  spearman
# 0                 5         2624     1  0.161250  0.108585  0.420016
# 1                 5         2624     2  0.171261  0.113140  0.447045
# 2                 5         2624     3  0.164081  0.107805  0.420559
# 3                 5         2624     4  0.165418  0.110346  0.421631
# 4                 5         2624     5  0.181403  0.110245  0.490806

# %%
extra_trees_threshold_summary = (
    extra_trees_cv_results
    .groupby(
        [
            "minimum_profiles",
            "n_compounds",
        ],
        as_index=False,
    )
    .agg(
        mean_r2=("r2", "mean"),
        std_r2=("r2", "std"),
        mean_spearman=("spearman", "mean"),
        std_spearman=("spearman", "std"),
        mean_mae=("mae", "mean"),
        std_mae=("mae", "std"),
    )
    .sort_values(
        "minimum_profiles"
    )
    .reset_index(drop=True)
)

display(extra_trees_threshold_summary)
# Out:
#    minimum_profiles  n_compounds   mean_r2    std_r2  mean_spearman  \
# 0                 5         2624  0.169811  0.017349       0.443553
# 1                10         1463  0.157282  0.025239       0.414872
# 2                20          801  0.127809  0.030799       0.371390
# 3                25          700  0.116413  0.057109       0.363187
# 4                50          478  0.176162  0.083079       0.415382
# 5                75          398  0.164928  0.079992       0.404397
# 6               100          349  0.219176  0.090910       0.448903
#
#    std_spearman  mean_mae   std_mae
# 0      0.032598  0.110029  0.003462
# 1      0.042369  0.086766  0.003218
# 2      0.055248  0.063602  0.001963
# 3      0.064208  0.059303  0.003785
# 4      0.095527  0.052793  0.002422
# 5      0.070103  0.054802  0.003821
# 6      0.094591  0.055049  0.003254

# %%
OUTPUT_PATH = (
    PROJECT_ROOT
    / "models"
    / "step4_extra_trees_repeated_cv_threshold_sweep.csv"
)

SUMMARY_PATH = (
    PROJECT_ROOT
    / "models"
    / "step4_extra_trees_repeated_cv_threshold_summary.csv"
)

extra_trees_cv_results.to_csv(
    OUTPUT_PATH,
    index=False,
)

extra_trees_threshold_summary.to_csv(
    SUMMARY_PATH,
    index=False,
)

print("Saved fold-level results:")
print(OUTPUT_PATH)

print("\nSaved threshold summary:")
print(SUMMARY_PATH)
# Out:
# Saved fold-level results:
# /Users/mell/predicting-predictability/models/step4_extra_trees_repeated_cv_threshold_sweep.csv
#
# Saved threshold summary:
# /Users/mell/predicting-predictability/models/step4_extra_trees_repeated_cv_threshold_summary.csv

# %%
import nbformat
from pathlib import Path

notebook_paths = [
    DATA_DIR / "part4_predicting.ipynb",
    DATA_DIR / "july_wraps.ipynb",
]

search_terms = [
    "feature_cols",
    "feature_columns",
    "n_features",
    "mean_compound_reconstruction_bce",
    "mean_compound_bitwise_accuracy",
    "n_profiles",
    "latent_cols",
    "x_train",
    "extratreesregressor",
]

for notebook_path in notebook_paths:
    print("\n" + "#" * 100)
    print("NOTEBOOK:", notebook_path)
    print("Exists:", notebook_path.exists())

    if not notebook_path.exists():
        continue

    notebook = nbformat.read(notebook_path, as_version=4)

    for cell_number, cell in enumerate(notebook.cells):
        if cell.cell_type != "code":
            continue

        source_lower = cell.source.lower()

        if any(term.lower() in source_lower for term in search_terms):
            print("\n" + "=" * 100)
            print(f"CELL {cell_number}")
            print(cell.source[:4000])
# Out:
# ####################################################################################################
# NOTEBOOK: /Users/mell/predicting-predictability/data/part4_predicting.ipynb
# Exists: True
#
# ####################################################################################################
# NOTEBOOK: /Users/mell/predicting-predictability/data/july_wraps.ipynb
# Exists: True
#
# ====================================================================================================
# CELL 110
# # Step 3: build clean multimodal model table from improved matched signatures
#
# from pathlib import Path
# import numpy as np
# import pandas as pd
# import re
#
# PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "data" else Path.cwd()
# DATA_DIR = PROJECT_ROOT / "data"
# STEP3_DIR = DATA_DIR / "step3_multimodal"
#
# STEP3_DIR.mkdir(parents=True, exist_ok=True)
#
# matched_path = STEP3_DIR / "step3_signature_to_compound_matched_table_improved.csv"
#
# matched = pd.read_csv(matched_path, low_memory=False)
#
# print("Improved matched table shape:", matched.shape)
# print("Columns:")
# print(matched.columns.tolist())
#
# # Keep only successfully matched compound-signature observations
# model_table = matched[matched["compound_embedding_row_index"].notna()].copy()
#
# model_table["compound_embedding_row_index"] = model_table["compound_embedding_row_index"].astype(int)
# model_table["signature_row_index"] = model_table["signature_row_index"].astype(int)
#
# print("\nUsable Step 3 rows:", model_table.shape)
# print("Unique compounds:", model_table["compound_embedding_row_index"].nunique())
# print("Unique signatures:", model_table["signature_row_index"].nunique())
#
#
# # Parse context from signature_id
#
# def parse_signature_parts(sig):
#     """
#     Parses signatures like:
#     L1000::bortezomib::HT29::::24H::20uM::REP...
#     L1000::torin-1::HAP1.CDK4::::24H::3.33uM::...
#
#     Returns:
#     source prefix, compound, cell line, time, dose
#     """
#     if pd.isna(sig):
#         return pd.Series({
#             "parsed_source_prefix": np.nan,
#             "parsed_compound": np.nan,
#             "parsed_cell_line": np.nan,
#             "parsed_time": np.nan,
#             "parsed_dose": np.nan,
#         })
#
#     parts = [p.strip() for p in str(sig).split("::") if p.strip() != ""]
#
#     source_prefix = parts[0] if len(parts) > 0 else np.nan
#     compound = parts[1] if len(parts) > 1 else np.nan
#     cell_line = parts[2] if len(parts) > 2 else np.nan
#
#     time = np.nan
#     dose = np.nan
#
#     for p in parts:
#         p_clean = p.strip()
#
#         # examples: 24H, 6H, 48H
#         if re.fullmatch(r"\d+(\.\d+)?\s*[Hh]", p_clean):
#             time = p_clean
#
#         # examples: 20uM, 3.33uM, 0.66uM, 10nM
#         if re.fullmatch(r"\d+(\.\d+)?\s*(uM|µM|nM|mM|M)", p_clean, flags=re.IGNORECASE):
#             dose = p_clean
#
#     return pd.Series({
#         "parsed_source_prefix": source_prefix,
#         "parsed_compound": compound,
#         "parsed_cell_line": cell_line,
#         "parsed_time": time,
#         "parsed_dose": dose,
#     })
#
#
# parsed = model_table["signature_id"].apply(parse_signature_parts)
# model_table = pd.concat([model_table, parsed], axis=1)
#
#
# # Select clean columns for downstream model
#
# keep_cols = [
#     # row indices
#     "signature_row_index",
#     "compound_embedding_row_index",
#
#     # match info
#     "match_method",
#
#     # identifiers
#     "source",
#     "signature_id",
#     "base_term",
#     "signature_compound_query",
#     "signature_brd_primary",
#     "compound_name",
#     "pert_id",
#     "canonical_smiles",
#     "inchi_key",
#     "pubchem_cid",
#     "moa",
#     "target",
#
#     # parsed context
#     "parsed_source_prefix",
#     "parsed_compound",
#     "parsed_cell_line",
#     "parsed_time",
#     "parsed_dose",
#
#     # Step 1 compound QC/error features
#     "compound_reconstruction_bce",
#     "compound_bitwise_accuracy",
#
#     # Step 2 signature QC/error features
#     "signature_reconstruction_loss",
#     "signature_nonzero_mse",
#     "signature_zero_mse",
#     "signature_nonzero_sign_accuracy",
#     "signature_nonzero_gene_count",
#
#     # signature split
#     "split",
# ]
#
# keep_cols = [c for c in keep_cols if c in model_table.columns]
# model_table = model_table[keep_cols].copy()
#
#
# # Save model table
#
# out_path = STEP3_DIR / "step3_multimodal_model_table_matched_improved.csv"
# model_table.to_csv(out_path, index=False)
#
#
# # Summary tables
#
# summary_by_source = (
#     model_table
#     .groupby("source")
#     .agg(
#         n=("signature_row_index", "count"),
#         unique_compounds=("compound_embedding_row_index", "nunique"),
#         m
#
# ====================================================================================================
# CELL 115
# # Step 3 Autoencoder: row-level errors + compound-level predictability values
#
# from pathlib import Path
# import numpy as np
# import pandas as pd
# import torch
# from torch import nn
# import torch.nn.functional as F
# import gc
#
# PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "data" else Path.cwd()
# DATA_DIR = PROJECT_ROOT / "data"
# MODEL_DIR = PROJECT_ROOT / "models"
# STEP3_DIR = DATA_DIR / "step3_multimodal"
#
# arrays_path = STEP3_DIR / "step3_bowtie_arrays_first_pass.npz"
# row_metadata_path = STEP3_DIR / "step3_bowtie_row_metadata_first_pass.csv"
# best_model_path = MODEL_DIR / "step3_bowtie_autoencoder_first_pass_best.pt"
#
# row_errors_path = STEP3_DIR / "step3_bowtie_row_errors_first_pass.csv"
# compound_predictability_path = STEP3_DIR / "step3_compound_predictability_first_pass.csv"
# summary_path = STEP3_DIR / "step3_compound_predictability_first_pass_summary.txt"
#
#
# # Load data
#
# arrays = np.load(arrays_path)
# X = arrays["X_bowtie"].astype(np.float32)
#
# train_idx = arrays["train_idx"]
# val_idx = arrays["val_idx"]
# test_idx = arrays["test_idx"]
#
# compound_start = int(arrays["compound_start"])
# compound_end = int(arrays["compound_end"])
# signature_start = int(arrays["signature_start"])
# signature_end = int(arrays["signature_end"])
# numeric_start = int(arrays["numeric_context_start"])
# numeric_end = int(arrays["numeric_context_end"])
# cat_start = int(arrays["categorical_context_start"])
# cat_end = int(arrays["categorical_context_end"])
#
# row_metadata = pd.read_csv(row_metadata_path, low_memory=False)
#
# print("X:", X.shape)
# print("Row metadata:", row_metadata.shape)
#
#
# # Device
#
# if torch.backends.mps.is_available():
#     device = torch.device("mps")
# elif torch.cuda.is_available():
#     device = torch.device("cuda")
# else:
#     device = torch.device("cpu")
#
# print("Device:", device)
#
# INPUT_DIM = X.shape[1]
# LATENT_DIM = 128
# BATCH_SIZE = 512
#
#
# # Model definition must match training
#
# class BowtieAutoencoder(nn.Module):
#     def __init__(self, input_dim, latent_dim):
#         super().__init__()
#
#         self.encoder = nn.Sequential(
#             nn.Linear(input_dim, 512),
#             nn.ReLU(),
#             nn.Linear(512, 256),
#             nn.ReLU(),
#             nn.Linear(256, latent_dim),
#         )
#
#         self.decoder = nn.Sequential(
#             nn.Linear(latent_dim, 256),
#             nn.ReLU(),
#             nn.Linear(256, 512),
#             nn.ReLU(),
#             nn.Linear(512, input_dim),
#         )
#
#     def forward(self, x):
#         z = self.encoder(x)
#         recon = self.decoder(z)
#         return recon, z
#
# checkpoint = torch.load(best_model_path, map_location="cpu")
#
# model = BowtieAutoencoder(INPUT_DIM, LATENT_DIM)
# model.load_state_dict(checkpoint["model_state_dict"])
# model = model.to(device)
# model.eval()
#
# print("Loaded best model:", best_model_path)
# print("Best epoch:", checkpoint.get("epoch"))
# print("Best val loss:", checkpoint.get("best_val_loss"))
#
#
# # Compute row-level errors
#
# n = X.shape[0]
#
# total_error = np.zeros(n, dtype=np.float32)
# compound_mse = np.zeros(n, dtype=np.float32)
# signature_mse = np.zeros(n, dtype=np.float32)
# numeric_mse = np.zeros(n, dtype=np.float32)
# categorical_bce = np.zeros(n, dtype=np.float32)
#
# latent_embeddings = np.zeros((n, LATENT_DIM), dtype=np.float32)
#
# with torch.no_grad():
#     for start in range(0, n, BATCH_SIZE):
#         end = min(start + BATCH_SIZE, n)
#
#         batch = torch.from_numpy(X[start:end]).to(device)
#         recon, z = model(batch)
#
#         # component-wise per-row errors
#         compound_err = ((recon[:, compound_start:compound_end] - batch[:, compound_start:compound_end]) ** 2).mean(dim=1)
#         signature_err = ((recon[:, signature_start:signature_end] - batch[:, signature_start:signature_end]) ** 2).mean(dim=1)
#         numeric_err = ((recon[:, numeric_start:numeric_end] - batch[:, numeric_start:numeric_end]) ** 2).mean(dim=1)
#
#         cat_err = F.binary_cross_entropy_with_logits(
#             recon[:, cat_start:cat_end],
#             batch[:, cat_start:cat_end],
#             reduction="none"
#         ).mean(dim=1)
#
#
#
# ====================================================================================================
# CELL 116
# # Step 3 Bowtie Autoencoder: training curves + predictability/error plots
#
# from pathlib import Path
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
#
# PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "data" else Path.cwd()
# DATA_DIR = PROJECT_ROOT / "data"
# MODEL_DIR = PROJECT_ROOT / "models"
# STEP3_DIR = DATA_DIR / "step3_multimodal"
# FIG_DIR = PROJECT_ROOT / "figures" / "step3_bowtie_autoencoder"
#
# FIG_DIR.mkdir(parents=True, exist_ok=True)
#
# metrics_path = MODEL_DIR / "step3_bowtie_autoencoder_first_pass_metrics.csv"
# row_errors_path = STEP3_DIR / "step3_bowtie_row_errors_first_pass.csv"
# compound_predictability_path = STEP3_DIR / "step3_compound_predictability_first_pass.csv"
#
# metrics = pd.read_csv(metrics_path)
# row_errors = pd.read_csv(row_errors_path, low_memory=False)
# compound_pred = pd.read_csv(compound_predictability_path, low_memory=False)
#
# print("Metrics:", metrics.shape)
# print("Row errors:", row_errors.shape)
# print("Compound predictability:", compound_pred.shape)
#
# plt.rcParams.update({
#     "font.size": 18,
#     "axes.titlesize": 24,
#     "axes.labelsize": 22,
#     "xtick.labelsize": 18,
#     "ytick.labelsize": 18,
#     "legend.fontsize": 16,
# })
#
# def save_show(path):
#     plt.tight_layout()
#     plt.savefig(path, dpi=300, bbox_inches="tight")
#     plt.show()
#     print("Saved:", path)
#
# # 1. Train vs validation total loss
# best_epoch = int(metrics.loc[metrics["val_loss"].idxmin(), "epoch"])
#
# plt.figure(figsize=(12, 8))
# plt.plot(metrics["epoch"], metrics["train_loss"], marker="o", linewidth=3, label="Train loss")
# plt.plot(metrics["epoch"], metrics["val_loss"], marker="o", linewidth=3, label="Validation loss")
# plt.axvline(best_epoch, linestyle="--", linewidth=2.5, label=f"Best epoch: {best_epoch}")
# plt.title("Step 3 Bowtie Autoencoder Training Curve")
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.legend()
# save_show(FIG_DIR / "step3_bowtie_train_val_loss_largefont.png")
#
# # 2. Validation component losses
# plt.figure(figsize=(12, 8))
# plt.plot(metrics["epoch"], metrics["val_compound_mse"], marker="o", linewidth=3, label="Compound MSE")
# plt.plot(metrics["epoch"], metrics["val_signature_mse"], marker="o", linewidth=3, label="Signature MSE")
# plt.plot(metrics["epoch"], metrics["val_numeric_mse"], marker="o", linewidth=3, label="Numeric context MSE")
# plt.plot(metrics["epoch"], metrics["val_categorical_bce"], marker="o", linewidth=3, label="Categorical context BCE")
# plt.axvline(best_epoch, linestyle="--", linewidth=2.5, label=f"Best epoch: {best_epoch}")
# plt.title("Step 3 Validation Loss Components")
# plt.xlabel("Epoch")
# plt.ylabel("Component Loss")
# plt.legend()
# save_show(FIG_DIR / "step3_bowtie_validation_component_losses_largefont.png")
#
# # 3. Row-level total error histogram
# plt.figure(figsize=(12, 8))
# plt.hist(row_errors["bowtie_total_error"].dropna(), bins=100)
# plt.title("Row-Level Bowtie Reconstruction Error")
# plt.xlabel("Bowtie reconstruction error")
# plt.ylabel("Number of compound-signature profiles")
# save_show(FIG_DIR / "step3_row_total_error_histogram_largefont.png")
#
# # 4. Compound-level mean error histogram
# plt.figure(figsize=(12, 8))
# plt.hist(compound_pred["mean_total_error"].dropna(), bins=100)
# plt.title("Compound-Level Mean Bowtie Error")
# plt.xlabel("Mean reconstruction error per compound")
# plt.ylabel("Number of compounds")
# save_show(FIG_DIR / "step3_compound_mean_error_histogram_largefont.png")
#
# # 5. Compound-level variance histogram
# plt.figure(figsize=(12, 8))
# plt.hist(compound_pred["variance_total_error"].dropna(), bins=100)
# plt.title("Compound-Level Error Variance")
# plt.xlabel("Variance of reconstruction error per compound")
# plt.ylabel("Number of compounds")
# save_show(FIG_DIR / "step3_compound_error_variance_histogram_largefont.png")
#
# # 6. Mean error vs variance error
# plt.figure(figsize=(12, 8))
# plt.scatter(
#     compound_pred["mean_total_error"],
#     compound_pred["variance_total_error"],
#     s=np.clip(compound_pred["n_profiles"], 1, 200),
#     alpha=0.35,
# )
# plt.title("Compound Mean Error vs Error Variance")
# pl
#
# ====================================================================================================
# CELL 121
# # Step 3 Autoencoder: final 256D row-level errors + compound-level predictability
#
# from pathlib import Path
# import numpy as np
# import pandas as pd
# import torch
# from torch import nn
# import torch.nn.functional as F
# import gc
#
# PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "data" else Path.cwd()
# DATA_DIR = PROJECT_ROOT / "data"
# MODEL_DIR = PROJECT_ROOT / "models"
# STEP3_DIR = DATA_DIR / "step3_multimodal"
#
# arrays_path = STEP3_DIR / "step3_bowtie_arrays_first_pass.npz"
# row_metadata_path = STEP3_DIR / "step3_bowtie_row_metadata_first_pass.csv"
#
# best_model_path = MODEL_DIR / "step3_bowtie_autoencoder_latent256_best.pt"
#
# row_errors_path = STEP3_DIR / "step3_bowtie_row_errors_latent256_final.csv"
# compound_predictability_path = STEP3_DIR / "step3_compound_predictability_latent256_final.csv"
# summary_path = STEP3_DIR / "step3_compound_predictability_latent256_final_summary.txt"
#
#
# # Load arrays and metadata
#
# arrays = np.load(arrays_path)
# X = arrays["X_bowtie"].astype(np.float32)
#
# train_idx = arrays["train_idx"]
# val_idx = arrays["val_idx"]
# test_idx = arrays["test_idx"]
#
# compound_start = int(arrays["compound_start"])
# compound_end = int(arrays["compound_end"])
# signature_start = int(arrays["signature_start"])
# signature_end = int(arrays["signature_end"])
# numeric_start = int(arrays["numeric_context_start"])
# numeric_end = int(arrays["numeric_context_end"])
# cat_start = int(arrays["categorical_context_start"])
# cat_end = int(arrays["categorical_context_end"])
#
# row_metadata = pd.read_csv(row_metadata_path, low_memory=False)
#
# print("X:", X.shape)
# print("Row metadata:", row_metadata.shape)
#
#
# # Device
#
# if torch.backends.mps.is_available():
#     device = torch.device("mps")
# elif torch.cuda.is_available():
#     device = torch.device("cuda")
# else:
#     device = torch.device("cpu")
#
# print("Device:", device)
#
# INPUT_DIM = X.shape[1]
# LATENT_DIM = 256
# BATCH_SIZE = 512
#
#
# # Model definition
#
# class BowtieAutoencoder(nn.Module):
#     def __init__(self, input_dim, latent_dim):
#         super().__init__()
#
#         self.encoder = nn.Sequential(
#             nn.Linear(input_dim, 512),
#             nn.ReLU(),
#             nn.Linear(512, 256),
#             nn.ReLU(),
#             nn.Linear(256, latent_dim),
#         )
#
#         self.decoder = nn.Sequential(
#             nn.Linear(latent_dim, 256),
#             nn.ReLU(),
#             nn.Linear(256, 512),
#             nn.ReLU(),
#             nn.Linear(512, input_dim),
#         )
#
#     def forward(self, x):
#         z = self.encoder(x)
#         recon = self.decoder(z)
#         return recon, z
#
#
# checkpoint = torch.load(best_model_path, map_location="cpu")
#
# model = BowtieAutoencoder(INPUT_DIM, LATENT_DIM)
# model.load_state_dict(checkpoint["model_state_dict"])
# model = model.to(device)
# model.eval()
#
# print("Loaded best 256D model:", best_model_path)
# print("Best epoch:", checkpoint.get("epoch"))
# print("Best val loss:", checkpoint.get("best_val_loss"))
#
#
# # Compute row-level errors
#
# n = X.shape[0]
#
# total_error = np.zeros(n, dtype=np.float32)
# compound_mse = np.zeros(n, dtype=np.float32)
# signature_mse = np.zeros(n, dtype=np.float32)
# numeric_mse = np.zeros(n, dtype=np.float32)
# categorical_bce = np.zeros(n, dtype=np.float32)
#
# with torch.no_grad():
#     for start in range(0, n, BATCH_SIZE):
#         end = min(start + BATCH_SIZE, n)
#
#         batch = torch.from_numpy(X[start:end]).to(device)
#         recon, _ = model(batch)
#
#         compound_err = (
#             (recon[:, compound_start:compound_end] - batch[:, compound_start:compound_end]) ** 2
#         ).mean(dim=1)
#
#         signature_err = (
#             (recon[:, signature_start:signature_end] - batch[:, signature_start:signature_end]) ** 2
#         ).mean(dim=1)
#
#         numeric_err = (
#             (recon[:, numeric_start:numeric_end] - batch[:, numeric_start:numeric_end]) ** 2
#         ).mean(dim=1)
#
#         cat_err = F.binary_cross_entropy_with_logits(
#             recon[:, cat_start:cat_end],
#             batch[:, cat_start:cat_end],
#             reduction="none"
#         ).mean(dim=1)
#
#         total = com
#
# ====================================================================================================
# CELL 122
# # Step 3 Autoencoder: final 256D predictability plots
#
# from pathlib import Path
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
#
# PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "data" else Path.cwd()
# DATA_DIR = PROJECT_ROOT / "data"
# STEP3_DIR = DATA_DIR / "step3_multimodal"
# FIG_DIR = PROJECT_ROOT / "figures" / "step3_bowtie_autoencoder"
#
# FIG_DIR.mkdir(parents=True, exist_ok=True)
#
# compound_path = STEP3_DIR / "step3_compound_predictability_latent256_final.csv"
# row_errors_path = STEP3_DIR / "step3_bowtie_row_errors_latent256_final.csv"
#
# compound_pred = pd.read_csv(compound_path, low_memory=False)
# row_errors = pd.read_csv(row_errors_path, low_memory=False)
#
# print("Compound predictability:", compound_pred.shape)
# print("Row errors:", row_errors.shape)
#
# plt.rcParams.update({
#     "font.size": 18,
#     "axes.titlesize": 24,
#     "axes.labelsize": 22,
#     "xtick.labelsize": 18,
#     "ytick.labelsize": 18,
#     "legend.fontsize": 16,
# })
#
# def save_show(path):
#     plt.tight_layout()
#     plt.savefig(path, dpi=300, bbox_inches="tight")
#     plt.show()
#     print("Saved:", path)
#
#
# # 1. Compound mean error distribution
#
# plt.figure(figsize=(12, 8))
# plt.hist(compound_pred["mean_total_error"].dropna(), bins=100)
# plt.title("Compound-Level Mean Bowtie Error")
# plt.xlabel("Mean reconstruction error per compound")
# plt.ylabel("Number of compounds")
# save_show(FIG_DIR / "step3_final256_compound_mean_error_histogram.png")
#
#
# # 2. Compound error variance distribution
#
# plt.figure(figsize=(12, 8))
# plt.hist(compound_pred["variance_total_error"].dropna(), bins=100)
# plt.title("Compound-Level Error Variance")
# plt.xlabel("Variance of reconstruction error per compound")
# plt.ylabel("Number of compounds")
# save_show(FIG_DIR / "step3_final256_compound_error_variance_histogram.png")
#
#
# # 3. Predictability score distribution
#
# plt.figure(figsize=(12, 8))
# plt.hist(compound_pred["predictability_score"].dropna(), bins=100)
# plt.title("Compound Predictability Score Distribution")
# plt.xlabel("Predictability score")
# plt.ylabel("Number of compounds")
# save_show(FIG_DIR / "step3_final256_predictability_score_histogram.png")
#
#
# # 4. Mean error vs variance
#
# plot_df = compound_pred.copy()
#
# # cap point sizes so compounds with thousands of profiles don't dominate
# sizes = np.clip(plot_df["n_profiles"], 1, 200)
#
# plt.figure(figsize=(12, 8))
# plt.scatter(
#     plot_df["mean_total_error"],
#     plot_df["variance_total_error"],
#     s=sizes,
#     alpha=0.35,
# )
# plt.title("Compound Mean Error vs Error Variance")
# plt.xlabel("Mean reconstruction error")
# plt.ylabel("Variance of reconstruction error")
# save_show(FIG_DIR / "step3_final256_compound_mean_error_vs_variance.png")
#
#
# # 5. Mean error vs number of profiles
#
# plt.figure(figsize=(12, 8))
# plt.scatter(
#     compound_pred["n_profiles"],
#     compound_pred["mean_total_error"],
#     s=20,
#     alpha=0.35,
# )
# plt.title("Compound Mean Error vs Number of Profiles")
# plt.xlabel("Number of profiled signatures")
# plt.ylabel("Mean reconstruction error")
# save_show(FIG_DIR / "step3_final256_mean_error_vs_n_profiles.png")
#
#
# # 6. Predictability score vs number of profiles
#
# plt.figure(figsize=(12, 8))
# plt.scatter(
#     compound_pred["n_profiles"],
#     compound_pred["predictability_score"],
#     s=20,
#     alpha=0.35,
# )
# plt.title("Predictability Score vs Number of Profiles")
# plt.xlabel("Number of profiled signatures")
# plt.ylabel("Predictability score")
# save_show(FIG_DIR / "step3_final256_predictability_vs_n_profiles.png")
#
#
# # 7. Row-level total error distribution
#
# plt.figure(figsize=(12, 8))
# plt.hist(row_errors["bowtie_total_error"].dropna(), bins=100)
# plt.title("Row-Level Bowtie Reconstruction Error")
# plt.xlabel("Reconstruction error per compound-signature profile")
# plt.ylabel("Number of profiles")
# save_show(FIG_DIR / "step3_final256_row_total_error_histogram.png")
#
#
# # 8. Row-level signature error distribution
#
# plt.figure(figsize=(12, 8))
# plt.hist(row_errors["bowtie_signature_mse"].dropna(), bins=100)
# plt.title("Row-Level Signature Reconstruction Error"
#
# ====================================================================================================
# CELL 123
# # Step 3 final 256D: improved diagnostics + source-normalized predictability plots
#
# from pathlib import Path
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
#
# PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "data" else Path.cwd()
# DATA_DIR = PROJECT_ROOT / "data"
# STEP3_DIR = DATA_DIR / "step3_multimodal"
# FIG_DIR = PROJECT_ROOT / "figures" / "step3_bowtie_autoencoder"
#
# FIG_DIR.mkdir(parents=True, exist_ok=True)
#
# compound_path = STEP3_DIR / "step3_compound_predictability_latent256_final.csv"
# row_errors_path = STEP3_DIR / "step3_bowtie_row_errors_latent256_final.csv"
#
# compound_pred = pd.read_csv(compound_path, low_memory=False)
# row_errors = pd.read_csv(row_errors_path, low_memory=False)
#
# print("Compound predictability:", compound_pred.shape)
# print("Row errors:", row_errors.shape)
#
#
# # Add source-normalized row error
#
# source_stats = (
#     row_errors
#     .groupby("source")
#     .agg(
#         source_mean_total_error=("bowtie_total_error", "mean"),
#         source_std_total_error=("bowtie_total_error", "std"),
#         source_n=("bowtie_total_error", "count"),
#     )
#     .reset_index()
# )
#
# row_errors_norm = row_errors.merge(source_stats, on="source", how="left")
# row_errors_norm["source_std_total_error"] = row_errors_norm["source_std_total_error"].replace(0, np.nan)
#
# row_errors_norm["source_normalized_total_error_z"] = (
#     (row_errors_norm["bowtie_total_error"] - row_errors_norm["source_mean_total_error"])
#     / row_errors_norm["source_std_total_error"]
# )
#
# # Fallback if a source has std 0
# row_errors_norm["source_normalized_total_error_z"] = row_errors_norm["source_normalized_total_error_z"].fillna(0)
#
#
# # Aggregate source-normalized errors by compound
#
# compound_source_norm = (
#     row_errors_norm
#     .groupby(["compound_embedding_row_index", "compound_name"], dropna=False)
#     .agg(
#         n_profiles=("signature_row_index", "count"),
#         mean_source_normalized_error_z=("source_normalized_total_error_z", "mean"),
#         variance_source_normalized_error_z=("source_normalized_total_error_z", "var"),
#         std_source_normalized_error_z=("source_normalized_total_error_z", "std"),
#         median_source_normalized_error_z=("source_normalized_total_error_z", "median"),
#         n_sources=("source", "nunique"),
#     )
#     .reset_index()
# )
#
# for col in ["variance_source_normalized_error_z", "std_source_normalized_error_z"]:
#     compound_source_norm[col] = compound_source_norm[col].fillna(0)
#
# # merge onto compound table
# compound_pred2 = compound_pred.merge(
#     compound_source_norm,
#     on=["compound_embedding_row_index", "compound_name", "n_profiles"],
#     how="left"
# )
#
# # Lower source-normalized error = more predictable relative to source
# compound_pred2["source_normalized_error_percentile"] = (
#     compound_pred2["mean_source_normalized_error_z"].rank(pct=True)
# )
#
# compound_pred2["source_normalized_predictability_score"] = (
#     1 - compound_pred2["source_normalized_error_percentile"]
# )
#
# # Profile-count bins
# bins = [0, 1, 4, 19, 99, np.inf]
# labels = ["1", "2-4", "5-19", "20-99", "100+"]
#
# compound_pred2["profile_count_bin"] = pd.cut(
#     compound_pred2["n_profiles"],
#     bins=bins,
#     labels=labels,
#     include_lowest=True
# )
#
# # Save updated tables
# updated_compound_path = STEP3_DIR / "step3_compound_predictability_latent256_final_with_source_normalized.csv"
# updated_row_path = STEP3_DIR / "step3_bowtie_row_errors_latent256_final_with_source_normalized.csv"
#
# compound_pred2.to_csv(updated_compound_path, index=False)
# row_errors_norm.to_csv(updated_row_path, index=False)
#
# print("Saved updated compound predictability:", updated_compound_path)
# print("Saved updated row errors:", updated_row_path)
#
#
# # Plot settings
#
# plt.rcParams.update({
#     "font.size": 18,
#     "axes.titlesize": 24,
#     "axes.labelsize": 22,
#     "xtick.labelsize": 18,
#     "ytick.labelsize": 18,
#     "legend.fontsize": 16,
# })
#
# def save_show(path):
#     plt.tight_layout()
#     plt.savefig(path, dpi=300, bbox_inches="tight")
#     plt.show()
#     print("Saved:", path)
#
#
# ====================================================================================================
# CELL 124
# # Step 3 final 256D: profile-count confound diagnostics
#
# from pathlib import Path
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
#
# PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "data" else Path.cwd()
# DATA_DIR = PROJECT_ROOT / "data"
# STEP3_DIR = DATA_DIR / "step3_multimodal"
# FIG_DIR = PROJECT_ROOT / "figures" / "step3_bowtie_autoencoder"
#
# FIG_DIR.mkdir(parents=True, exist_ok=True)
#
# compound_path = STEP3_DIR / "step3_compound_predictability_latent256_final_with_source_normalized.csv"
# compound_pred = pd.read_csv(compound_path, low_memory=False)
#
# print("Compound predictability:", compound_pred.shape)
#
#
# # Make profile count bins if needed
#
# bins = [0, 1, 4, 19, 99, np.inf]
# labels = ["1", "2-4", "5-19", "20-99", "100+"]
#
# compound_pred["profile_count_bin"] = pd.cut(
#     compound_pred["n_profiles"],
#     bins=bins,
#     labels=labels,
#     include_lowest=True
# )
#
#
# # Summary table by profile-count bin
#
# profile_bin_summary = (
#     compound_pred
#     .groupby("profile_count_bin", observed=True)
#     .agg(
#         n_compounds=("compound_embedding_row_index", "count"),
#         median_n_profiles=("n_profiles", "median"),
#
#         mean_error=("mean_total_error", "mean"),
#         median_error=("mean_total_error", "median"),
#         q25_error=("mean_total_error", lambda x: x.quantile(0.25)),
#         q75_error=("mean_total_error", lambda x: x.quantile(0.75)),
#
#         mean_source_normalized_error=("mean_source_normalized_error_z", "mean"),
#         median_source_normalized_error=("mean_source_normalized_error_z", "median"),
#         q25_source_normalized_error=("mean_source_normalized_error_z", lambda x: x.quantile(0.25)),
#         q75_source_normalized_error=("mean_source_normalized_error_z", lambda x: x.quantile(0.75)),
#
#         median_variance=("variance_total_error", "median"),
#         mean_variance=("variance_total_error", "mean"),
#     )
#     .reset_index()
# )
#
# summary_path = STEP3_DIR / "step3_final256_profile_count_confound_summary.csv"
# profile_bin_summary.to_csv(summary_path, index=False)
#
# display(profile_bin_summary)
# print("Saved profile-count confound summary:", summary_path)
#
#
# # Correlations
#
# corr_summary = pd.DataFrame([
#     {
#         "comparison": "n_profiles vs mean_total_error",
#         "pearson": compound_pred["n_profiles"].corr(compound_pred["mean_total_error"], method="pearson"),
#         "spearman": compound_pred["n_profiles"].corr(compound_pred["mean_total_error"], method="spearman"),
#     },
#     {
#         "comparison": "n_profiles vs source_normalized_error",
#         "pearson": compound_pred["n_profiles"].corr(compound_pred["mean_source_normalized_error_z"], method="pearson"),
#         "spearman": compound_pred["n_profiles"].corr(compound_pred["mean_source_normalized_error_z"], method="spearman"),
#     },
#     {
#         "comparison": "n_profiles vs variance_total_error",
#         "pearson": compound_pred["n_profiles"].corr(compound_pred["variance_total_error"], method="pearson"),
#         "spearman": compound_pred["n_profiles"].corr(compound_pred["variance_total_error"], method="spearman"),
#     },
# ])
#
# corr_path = STEP3_DIR / "step3_final256_profile_count_correlations.csv"
# corr_summary.to_csv(corr_path, index=False)
#
# display(corr_summary)
# print("Saved correlations:", corr_path)
#
#
# # Plot settings
#
# plt.rcParams.update({
#     "font.size": 18,
#     "axes.titlesize": 24,
#     "axes.labelsize": 22,
#     "xtick.labelsize": 18,
#     "ytick.labelsize": 18,
#     "legend.fontsize": 16,
# })
#
# def save_show(path):
#     plt.tight_layout()
#     plt.savefig(path, dpi=300, bbox_inches="tight")
#     plt.show()
#     print("Saved:", path)
#
#
# # 1. Boxplot: raw mean error by profile-count bin
#
# box_data = [
#     compound_pred.loc[compound_pred["profile_count_bin"] == label, "mean_total_error"].dropna()
#     for label in labels
# ]
#
# plt.figure(figsize=(12, 8))
# plt.boxplot(box_data, labels=labels, showfliers=False)
# plt.title("Compound Mean Error by Number of Profiles")
# plt.xlabel("Number of profiled signatures per compound")
# plt.ylabel("Mean reconstruct
#
# ====================================================================================================
# CELL 125
# # Continue profile-count confound diagnostics after boxplot labels error
#
# from pathlib import Path
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
#
# PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "data" else Path.cwd()
# DATA_DIR = PROJECT_ROOT / "data"
# STEP3_DIR = DATA_DIR / "step3_multimodal"
# FIG_DIR = PROJECT_ROOT / "figures" / "step3_bowtie_autoencoder"
#
# FIG_DIR.mkdir(parents=True, exist_ok=True)
#
# # Reload if needed
# compound_path = STEP3_DIR / "step3_compound_predictability_latent256_final_with_source_normalized.csv"
# compound_pred = pd.read_csv(compound_path, low_memory=False)
#
# bins = [0, 1, 4, 19, 99, np.inf]
# labels = ["1", "2-4", "5-19", "20-99", "100+"]
#
# compound_pred["profile_count_bin"] = pd.cut(
#     compound_pred["n_profiles"],
#     bins=bins,
#     labels=labels,
#     include_lowest=True
# )
#
# profile_bin_summary_path = STEP3_DIR / "step3_final256_profile_count_confound_summary.csv"
# profile_bin_summary = pd.read_csv(profile_bin_summary_path)
#
# corr_path = STEP3_DIR / "step3_final256_profile_count_correlations.csv"
# corr_summary = pd.read_csv(corr_path)
#
# display(profile_bin_summary)
# display(corr_summary)
#
# plt.rcParams.update({
#     "font.size": 18,
#     "axes.titlesize": 24,
#     "axes.labelsize": 22,
#     "xtick.labelsize": 18,
#     "ytick.labelsize": 18,
#     "legend.fontsize": 16,
# })
#
# def save_show(path):
#     plt.tight_layout()
#     plt.savefig(path, dpi=300, bbox_inches="tight")
#     plt.show()
#     print("Saved:", path)
#
#
# # 1. Boxplot: raw mean error by profile-count bin
#
# box_data = [
#     compound_pred.loc[compound_pred["profile_count_bin"] == label, "mean_total_error"].dropna()
#     for label in labels
# ]
#
# plt.figure(figsize=(12, 8))
# plt.boxplot(box_data, tick_labels=labels, showfliers=False)
# plt.title("Compound Mean Error by Number of Profiles")
# plt.xlabel("Number of profiled signatures per compound")
# plt.ylabel("Mean reconstruction error")
# save_show(FIG_DIR / "step3_final256_boxplot_mean_error_by_profile_count_bin.png")
#
#
# # 2. Boxplot: source-normalized error by profile-count bin
#
# box_data_norm = [
#     compound_pred.loc[compound_pred["profile_count_bin"] == label, "mean_source_normalized_error_z"].dropna()
#     for label in labels
# ]
#
# plt.figure(figsize=(12, 8))
# plt.boxplot(box_data_norm, tick_labels=labels, showfliers=False)
# plt.axhline(0, linestyle="--", linewidth=2)
# plt.title("Source-Normalized Error by Number of Profiles")
# plt.xlabel("Number of profiled signatures per compound")
# plt.ylabel("Mean source-normalized error z-score")
# save_show(FIG_DIR / "step3_final256_boxplot_source_normalized_error_by_profile_count_bin.png")
#
#
# # 3. Median raw error with IQR by profile-count bin
#
# x = np.arange(len(profile_bin_summary))
#
# plt.figure(figsize=(12, 8))
# plt.errorbar(
#     x,
#     profile_bin_summary["median_error"],
#     yerr=[
#         profile_bin_summary["median_error"] - profile_bin_summary["q25_error"],
#         profile_bin_summary["q75_error"] - profile_bin_summary["median_error"],
#     ],
#     marker="o",
#     linewidth=3,
#     capsize=6,
# )
# plt.xticks(x, profile_bin_summary["profile_count_bin"].astype(str))
# plt.title("Median Compound Error Declines with More Profiles")
# plt.xlabel("Number of profiled signatures per compound")
# plt.ylabel("Median mean reconstruction error")
# save_show(FIG_DIR / "step3_final256_median_error_iqr_by_profile_count_bin.png")
#
#
# # 4. Median source-normalized error with IQR by profile-count bin
#
# plt.figure(figsize=(12, 8))
# plt.errorbar(
#     x,
#     profile_bin_summary["median_source_normalized_error"],
#     yerr=[
#         profile_bin_summary["median_source_normalized_error"] - profile_bin_summary["q25_source_normalized_error"],
#         profile_bin_summary["q75_source_normalized_error"] - profile_bin_summary["median_source_normalized_error"],
#     ],
#     marker="o",
#     linewidth=3,
#     capsize=6,
# )
# plt.axhline(0, linestyle="--", linewidth=2)
# plt.xticks(x, profile_bin_summary["profile_count_bin"].astype(str))
# plt.title("Median Source-Normalized Error by Profile Count")
# plt.xlabel("Number of pro
#
# ====================================================================================================
# CELL 126
# # Step 3 final 256D: high-confidence compound analysis
# # Focuses on compounds with enough profiles to make mean/variance estimates more reliable.
#
# from pathlib import Path
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
#
# PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "data" else Path.cwd()
# DATA_DIR = PROJECT_ROOT / "data"
# STEP3_DIR = DATA_DIR / "step3_multimodal"
# FIG_DIR = PROJECT_ROOT / "figures" / "step3_bowtie_autoencoder"
#
# FIG_DIR.mkdir(parents=True, exist_ok=True)
#
# compound_path = STEP3_DIR / "step3_compound_predictability_latent256_final_with_source_normalized.csv"
# compound_pred = pd.read_csv(compound_path, low_memory=False)
#
# print("All compounds:", compound_pred.shape)
#
# high20 = compound_pred[compound_pred["n_profiles"] >= 20].copy()
# high100 = compound_pred[compound_pred["n_profiles"] >= 100].copy()
#
# print("n_profiles >= 20:", high20.shape)
# print("n_profiles >= 100:", high100.shape)
#
# plt.rcParams.update({
#     "font.size": 18,
#     "axes.titlesize": 24,
#     "axes.labelsize": 22,
#     "xtick.labelsize": 18,
#     "ytick.labelsize": 18,
#     "legend.fontsize": 16,
# })
#
# def save_show(path):
#     plt.tight_layout()
#     plt.savefig(path, dpi=300, bbox_inches="tight")
#     plt.show()
#     print("Saved:", path)
#
# def clipped(s, q=0.99):
#     s = s.dropna()
#     cutoff = s.quantile(q)
#     return s[s <= cutoff], cutoff
#
#
# # 1. Mean error distribution for high-confidence compounds
#
# for label, df in [("n20", high20), ("n100", high100)]:
#     vals, cutoff = clipped(df["mean_total_error"], 0.99)
#
#     plt.figure(figsize=(12, 8))
#     plt.hist(vals, bins=60)
#     plt.title(f"Mean AE Error for High-Profile Compounds ({label})")
#     plt.xlabel("Mean reconstruction error per compound")
#     plt.ylabel("Number of compounds")
#     plt.figtext(0.02, 0.01, f"Filter: {label}; 99th percentile cutoff = {cutoff:.4f}", fontsize=14)
#     save_show(FIG_DIR / f"step3_final256_highconf_{label}_mean_error_histogram.png")
#
#
# # 2. Source-normalized error distribution for high-confidence compounds
#
# for label, df in [("n20", high20), ("n100", high100)]:
#     q01 = df["mean_source_normalized_error_z"].quantile(0.01)
#     q99 = df["mean_source_normalized_error_z"].quantile(0.99)
#
#     vals = df[
#         (df["mean_source_normalized_error_z"] >= q01)
#         & (df["mean_source_normalized_error_z"] <= q99)
#     ]["mean_source_normalized_error_z"]
#
#     plt.figure(figsize=(12, 8))
#     plt.hist(vals.dropna(), bins=60)
#     plt.axvline(0, linestyle="--", linewidth=2)
#     plt.title(f"Source-Normalized Error for High-Profile Compounds ({label})")
#     plt.xlabel("Mean source-normalized error z-score")
#     plt.ylabel("Number of compounds")
#     plt.figtext(0.02, 0.01, f"Clipped 1st-99th percentile: {q01:.2f} to {q99:.2f}", fontsize=14)
#     save_show(FIG_DIR / f"step3_final256_highconf_{label}_source_normalized_error_histogram.png")
#
#
# # 3. Mean error vs variance for high-confidence compounds
#
# for label, df in [("n20", high20), ("n100", high100)]:
#     mean_cut = df["mean_total_error"].quantile(0.99)
#     var_cut = df["variance_total_error"].quantile(0.99)
#
#     plot_df = df[
#         (df["mean_total_error"] <= mean_cut)
#         & (df["variance_total_error"] <= var_cut)
#     ].copy()
#
#     plt.figure(figsize=(12, 8))
#     plt.scatter(
#         plot_df["mean_total_error"],
#         plot_df["variance_total_error"],
#         s=np.clip(plot_df["n_profiles"], 20, 200),
#         alpha=0.35,
#     )
#     plt.title(f"Mean Error vs Error Variance ({label})")
#     plt.xlabel("Mean reconstruction error")
#     plt.ylabel("Variance of reconstruction error")
#     save_show(FIG_DIR / f"step3_final256_highconf_{label}_mean_error_vs_variance.png")
#
#
# # 4. High-confidence rankings
#
# rank_cols = [
#     "compound_embedding_row_index",
#     "compound_name",
#     "n_profiles",
#     "mean_total_error",
#     "variance_total_error",
#     "std_total_error",
#     "median_total_error",
#     "mean_source_normalized_error_z",
#     "variance_source_normalized_error_z",
#     "source_normalized_predictability_score",
# ]
#
# rank_c
#
# ====================================================================================================
# CELL 127
# # Step 3 final 256D: clearer predictability score plots
#
# from pathlib import Path
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
#
# PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "data" else Path.cwd()
# DATA_DIR = PROJECT_ROOT / "data"
# STEP3_DIR = DATA_DIR / "step3_multimodal"
# FIG_DIR = PROJECT_ROOT / "figures" / "step3_bowtie_autoencoder"
#
# FIG_DIR.mkdir(parents=True, exist_ok=True)
#
# compound_path = STEP3_DIR / "step3_compound_predictability_latent256_final_with_source_normalized.csv"
# compound_pred = pd.read_csv(compound_path, low_memory=False)
#
# print("Compound table:", compound_pred.shape)
#
#
# # Create a raw, non-percentile score too
#
# # Percentile score is useful for ranking but has a flat distribution by construction.
# # This robust score shows the actual shape of the error distribution.
# err = compound_pred["mean_total_error"].copy()
#
# q01 = err.quantile(0.01)
# q99 = err.quantile(0.99)
#
# err_clipped = err.clip(lower=q01, upper=q99)
#
# compound_pred["raw_error_inverted_score"] = 1 - (
#     (err_clipped - err_clipped.min()) / (err_clipped.max() - err_clipped.min())
# )
#
# # Source-normalized robust score
# sn = compound_pred["mean_source_normalized_error_z"].copy()
#
# sn_q01 = sn.quantile(0.01)
# sn_q99 = sn.quantile(0.99)
#
# sn_clipped = sn.clip(lower=sn_q01, upper=sn_q99)
#
# compound_pred["source_normalized_inverted_score"] = 1 - (
#     (sn_clipped - sn_clipped.min()) / (sn_clipped.max() - sn_clipped.min())
# )
#
# # Save updated score table
# score_path = STEP3_DIR / "step3_compound_predictability_latent256_final_scores.csv"
# compound_pred.to_csv(score_path, index=False)
# print("Saved updated score table:", score_path)
#
#
# # Plot settings
#
# plt.rcParams.update({
#     "font.size": 18,
#     "axes.titlesize": 24,
#     "axes.labelsize": 22,
#     "xtick.labelsize": 18,
#     "ytick.labelsize": 18,
#     "legend.fontsize": 16,
# })
#
# def save_show(path):
#     plt.tight_layout()
#     plt.savefig(path, dpi=300, bbox_inches="tight")
#     plt.show()
#     print("Saved:", path)
#
#
# # 1. Raw inverted predictability score distribution
#
# plt.figure(figsize=(12, 8))
# plt.hist(compound_pred["raw_error_inverted_score"].dropna(), bins=80)
# plt.title("Compound Predictability Score Distribution")
# plt.xlabel("Predictability score from AE error")
# plt.ylabel("Number of compounds")
# plt.figtext(
#     0.02,
#     0.01,
#     "Score = inverted mean AE error, clipped at 1st-99th percentiles. Higher = lower AE error.",
#     fontsize=13
# )
# save_show(FIG_DIR / "step3_final256_predictability_score_raw_inverted_distribution.png")
#
#
# # 2. Source-normalized predictability score distribution
#
# plt.figure(figsize=(12, 8))
# plt.hist(compound_pred["source_normalized_inverted_score"].dropna(), bins=80)
# plt.title("Source-Normalized Predictability Score Distribution")
# plt.xlabel("Source-normalized predictability score")
# plt.ylabel("Number of compounds")
# plt.figtext(
#     0.02,
#     0.01,
#     "Score = inverted source-normalized AE error. Higher = lower error relative to source.",
#     fontsize=13
# )
# save_show(FIG_DIR / "step3_final256_source_normalized_predictability_score_distribution.png")
#
#
# # 3. High-confidence score distribution
#
# high20 = compound_pred[compound_pred["n_profiles"] >= 20].copy()
# high100 = compound_pred[compound_pred["n_profiles"] >= 100].copy()
#
# for label, df in [("n20", high20), ("n100", high100)]:
#     plt.figure(figsize=(12, 8))
#     plt.hist(df["raw_error_inverted_score"].dropna(), bins=60)
#     plt.title(f"Predictability Scores for High-Profile Compounds ({label})")
#     plt.xlabel("Predictability score from AE error")
#     plt.ylabel("Number of compounds")
#     save_show(FIG_DIR / f"step3_final256_predictability_score_highconf_{label}.png")
#
#
# # 4. Predictability score vs error variance
#
# plot_df = high20.copy()
#
# # clip variance for readability
# var_cut = plot_df["variance_total_error"].quantile(0.99)
# plot_df = plot_df[plot_df["variance_total_error"] <= var_cut]
#
# plt.figure(figsize=(12, 8))
# plt.scatter(
#     plot_df["raw_error_inverted_score"],
#     plot_df["variance_total_error"],
#     s=np.cl
#
# ====================================================================================================
# CELL 128
# # Cleaner top/bottom high-confidence plots using mean AE error directly
#
# from pathlib import Path
# import pandas as pd
# import matplotlib.pyplot as plt
#
# PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "data" else Path.cwd()
# DATA_DIR = PROJECT_ROOT / "data"
# STEP3_DIR = DATA_DIR / "step3_multimodal"
# FIG_DIR = PROJECT_ROOT / "figures" / "step3_bowtie_autoencoder"
#
# compound_path = STEP3_DIR / "step3_compound_predictability_latent256_final_scores.csv"
# compound_pred = pd.read_csv(compound_path, low_memory=False)
#
# high20 = compound_pred[compound_pred["n_profiles"] >= 20].copy()
#
# plt.rcParams.update({
#     "font.size": 18,
#     "axes.titlesize": 24,
#     "axes.labelsize": 22,
#     "xtick.labelsize": 18,
#     "ytick.labelsize": 18,
#     "legend.fontsize": 16,
# })
#
# def save_show(path):
#     plt.tight_layout()
#     plt.savefig(path, dpi=300, bbox_inches="tight")
#     plt.show()
#     print("Saved:", path)
#
# # Top predictable: lowest mean AE error
# top20 = high20.sort_values("mean_total_error", ascending=True).head(20).copy()
# top20["compound_label"] = (
#     top20["compound_name"]
#     .astype(str)
#     .str.replace(r";.*", "", regex=True)
#     .str.slice(0, 35)
# )
#
# plt.figure(figsize=(14, 10))
# plt.barh(top20["compound_label"][::-1], top20["mean_total_error"][::-1])
# plt.title("Top High-Confidence Predictable Compounds")
# plt.xlabel("Mean AE reconstruction error")
# plt.ylabel("Compound")
# plt.figtext(
#     0.02,
#     0.01,
#     "Filtered to n_profiles ≥ 20. Lower mean AE error = higher predictability.",
#     fontsize=13
# )
# save_show(FIG_DIR / "step3_final256_top20_highconf_mean_AE_error.png")
#
# # Least predictable: highest mean AE error
# bottom20 = high20.sort_values("mean_total_error", ascending=False).head(20).copy()
# bottom20["compound_label"] = (
#     bottom20["compound_name"]
#     .astype(str)
#     .str.replace(r";.*", "", regex=True)
#     .str.slice(0, 35)
# )
#
# plt.figure(figsize=(14, 10))
# plt.barh(bottom20["compound_label"][::-1], bottom20["mean_total_error"][::-1])
# plt.title("Lowest High-Confidence Predictability Compounds")
# plt.xlabel("Mean AE reconstruction error")
# plt.ylabel("Compound")
# plt.figtext(
#     0.02,
#     0.01,
#     "Filtered to n_profiles ≥ 20. Higher mean AE error = lower predictability.",
#     fontsize=13
# )
# save_show(FIG_DIR / "step3_final256_bottom20_highconf_mean_AE_error.png")
#
# display(top20[["compound_name", "n_profiles", "mean_total_error", "variance_total_error", "raw_error_inverted_score"]])
# display(bottom20[["compound_name", "n_profiles", "mean_total_error", "variance_total_error", "raw_error_inverted_score"]])
#
# ====================================================================================================
# CELL 130
# # Step 4: Train compound-only models to predict AE-derived predictability scores
# # Goal: compound embedding --> predictability/error label
# # This is the part that lets us eventually score unprofiled compounds
#
# from pathlib import Path
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
#
# from sklearn.model_selection import train_test_split
# from sklearn.pipeline import make_pipeline
# from sklearn.preprocessing import StandardScaler
# from sklearn.linear_model import Ridge
# from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor
# from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
# from scipy.stats import spearmanr
#
# PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "data" else Path.cwd()
# DATA_DIR = PROJECT_ROOT / "data"
# MODEL_DIR = PROJECT_ROOT / "models"
# STEP1_EMBED_DIR = DATA_DIR / "step1_embeddings"
# STEP3_DIR = DATA_DIR / "step3_multimodal"
# FIG_DIR = PROJECT_ROOT / "figures" / "step4_predictability_regression"
#
# MODEL_DIR.mkdir(exist_ok=True)
# FIG_DIR.mkdir(parents=True, exist_ok=True)
#
#
# # Paths
#
# compound_embedding_path = STEP1_EMBED_DIR / "step1_drug_embeddings_128.npy"
# predictability_path = STEP3_DIR / "step3_compound_predictability_latent256_final_scores.csv"
#
# metrics_out_path = MODEL_DIR / "step4_predictability_regression_metrics.csv"
# predictions_out_path = STEP3_DIR / "step4_predictability_regression_test_predictions.csv"
#
#
# # Load data
#
# compound_embeddings = np.load(compound_embedding_path, mmap_mode="r")
# compound_pred = pd.read_csv(predictability_path, low_memory=False)
#
# print("Compound embeddings:", compound_embeddings.shape)
# print("Predictability table:", compound_pred.shape)
# print("Columns:", compound_pred.columns.tolist())
#
#
# # Choose training rows
#
# # Use n_profiles >= 20 because these labels are more stable.
# # Later can compare with n_profiles >= 5 or all compounds.
# MIN_PROFILES = 20
#
# train_table = compound_pred[
#     compound_pred["n_profiles"] >= MIN_PROFILES
# ].copy()
#
# train_table = train_table.dropna(
#     subset=[
#         "compound_embedding_row_index",
#         "mean_total_error",
#         "raw_error_inverted_score",
#         "variance_total_error",
#         "source_normalized_inverted_score",
#     ]
# ).copy()
#
# train_table["compound_embedding_row_index"] = train_table["compound_embedding_row_index"].astype(int)
#
# print("Training rows after filter:", train_table.shape)
# print("Unique compounds:", train_table["compound_embedding_row_index"].nunique())
#
#
# # Build X
#
# idx = train_table["compound_embedding_row_index"].values
# X_embed = compound_embeddings[idx].astype(np.float32)
#
# extra_feature_cols = []
#
# # These are allowed because they come from the compound autoencoder / structure alone,
# # not from expression signatures.
# if "mean_compound_reconstruction_bce" in train_table.columns:
#     extra_feature_cols.append("mean_compound_reconstruction_bce")
#
# if "mean_compound_bitwise_accuracy" in train_table.columns:
#     extra_feature_cols.append("mean_compound_bitwise_accuracy")
#
# if len(extra_feature_cols) > 0:
#     X_extra = train_table[extra_feature_cols].fillna(train_table[extra_feature_cols].median()).values.astype(np.float32)
#     X = np.concatenate([X_embed, X_extra], axis=1)
# else:
#     X = X_embed
#
# print("X shape:", X.shape)
# print("Extra features:", extra_feature_cols)
#
#
# # Targets
#
# targets = {
#     "mean_total_error": "Mean AE error",
#     "raw_error_inverted_score": "Predictability score",
#     "variance_total_error": "Error variance",
#     "source_normalized_inverted_score": "Source-normalized predictability score",
# }
#
#
# # Models
#
# models = {
#     "ridge": make_pipeline(
#         StandardScaler(),
#         Ridge(alpha=1.0)
#     ),
#     "random_forest": RandomForestRegressor(
#         n_estimators=300,
#         max_depth=None,
#         min_samples_leaf=3,
#         random_state=42,
#         n_jobs=-1
#     ),
#     "hist_gradient_boosting": HistGradientBoostingRegressor(
#         max_iter=300,
#         learning_rate=0.05,
#         max_leaf_nodes=31,
#         l2_regularization=0.01,
#
#
# ====================================================================================================
# CELL 132
# # Step 4: improved predictor sweep
# # Target: source-normalized predictability score
# # Filters: n_profiles >= 5, 20, 100
#
# from pathlib import Path
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import joblib
#
# from sklearn.model_selection import train_test_split
# from sklearn.pipeline import make_pipeline
# from sklearn.preprocessing import StandardScaler
# from sklearn.linear_model import Ridge
# from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor, ExtraTreesRegressor
# from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
# from scipy.stats import spearmanr
#
# PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "data" else Path.cwd()
# DATA_DIR = PROJECT_ROOT / "data"
# MODEL_DIR = PROJECT_ROOT / "models"
# STEP1_EMBED_DIR = DATA_DIR / "step1_embeddings"
# STEP3_DIR = DATA_DIR / "step3_multimodal"
# FIG_DIR = PROJECT_ROOT / "figures" / "step4_predictability_regression"
#
# MODEL_DIR.mkdir(exist_ok=True)
# FIG_DIR.mkdir(parents=True, exist_ok=True)
#
# compound_embedding_path = STEP1_EMBED_DIR / "step1_drug_embeddings_128.npy"
# predictability_path = STEP3_DIR / "step3_compound_predictability_latent256_final_scores.csv"
#
# metrics_out_path = MODEL_DIR / "step4_source_normalized_predictability_filter_sweep_metrics.csv"
# predictions_out_path = STEP3_DIR / "step4_source_normalized_predictability_filter_sweep_predictions.csv"
# best_model_out_path = MODEL_DIR / "step4_best_source_normalized_predictability_model.joblib"
#
# compound_embeddings = np.load(compound_embedding_path, mmap_mode="r")
# compound_pred = pd.read_csv(predictability_path, low_memory=False)
#
# print("Compound embeddings:", compound_embeddings.shape)
# print("Compound predictability table:", compound_pred.shape)
#
# TARGET = "source_normalized_inverted_score"
# target_label = "Source-normalized predictability score"
#
# profile_filters = [5, 20, 100]
#
# models = {
#     "ridge": make_pipeline(
#         StandardScaler(),
#         Ridge(alpha=1.0)
#     ),
#     "random_forest": RandomForestRegressor(
#         n_estimators=400,
#         max_depth=None,
#         min_samples_leaf=3,
#         random_state=42,
#         n_jobs=-1
#     ),
#     "extra_trees": ExtraTreesRegressor(
#         n_estimators=400,
#         max_depth=None,
#         min_samples_leaf=3,
#         random_state=42,
#         n_jobs=-1
#     ),
#     "hist_gradient_boosting": HistGradientBoostingRegressor(
#         max_iter=400,
#         learning_rate=0.04,
#         max_leaf_nodes=31,
#         l2_regularization=0.01,
#         random_state=42
#     ),
# }
#
# def rmse(y_true, y_pred):
#     return np.sqrt(mean_squared_error(y_true, y_pred))
#
# def safe_spearman(y_true, y_pred):
#     return spearmanr(y_true, y_pred).correlation
#
# all_metrics = []
# all_predictions = []
#
# best_spearman = -999
# best_model_info = None
# best_model_object = None
#
# for min_profiles in profile_filters:
#     table = compound_pred[
#         compound_pred["n_profiles"] >= min_profiles
#     ].copy()
#
#     table = table.dropna(
#         subset=[
#             "compound_embedding_row_index",
#             TARGET,
#             "mean_total_error",
#             "variance_total_error",
#             "raw_error_inverted_score",
#         ]
#     ).copy()
#
#     table["compound_embedding_row_index"] = table["compound_embedding_row_index"].astype(int)
#
#     idx = table["compound_embedding_row_index"].values
#     X_embed = compound_embeddings[idx].astype(np.float32)
#
#     extra_feature_cols = []
#
#     if "mean_compound_reconstruction_bce" in table.columns:
#         extra_feature_cols.append("mean_compound_reconstruction_bce")
#
#     if "mean_compound_bitwise_accuracy" in table.columns:
#         extra_feature_cols.append("mean_compound_bitwise_accuracy")
#
#     if len(extra_feature_cols) > 0:
#         X_extra = table[extra_feature_cols].fillna(table[extra_feature_cols].median()).values.astype(np.float32)
#         X = np.concatenate([X_embed, X_extra], axis=1)
#     else:
#         X = X_embed
#
#     y = table[TARGET].values.astype(np.float32)
#
#     print("\n" + "="*90)
#     print(f"Filter: n_profiles >= {mi
#
# ====================================================================================================
# CELL 133
# # Step 4: improved sweep plots
#
# from pathlib import Path
# import pandas as pd
# import matplotlib.pyplot as plt
#
# PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "data" else Path.cwd()
# DATA_DIR = PROJECT_ROOT / "data"
# MODEL_DIR = PROJECT_ROOT / "models"
# STEP3_DIR = DATA_DIR / "step3_multimodal"
# FIG_DIR = PROJECT_ROOT / "figures" / "step4_predictability_regression"
#
# FIG_DIR.mkdir(parents=True, exist_ok=True)
#
# metrics_path = MODEL_DIR / "step4_source_normalized_predictability_filter_sweep_metrics.csv"
# predictions_path = STEP3_DIR / "step4_source_normalized_predictability_filter_sweep_predictions.csv"
#
# metrics = pd.read_csv(metrics_path)
# predictions = pd.read_csv(predictions_path, low_memory=False)
#
# display(metrics.sort_values("spearman", ascending=False))
#
# plt.rcParams.update({
#     "font.size": 18,
#     "axes.titlesize": 24,
#     "axes.labelsize": 22,
#     "xtick.labelsize": 18,
#     "ytick.labelsize": 18,
#     "legend.fontsize": 16,
# })
#
# def save_show(path):
#     plt.tight_layout()
#     plt.savefig(path, dpi=300, bbox_inches="tight")
#     plt.show()
#     print("Saved:", path)
#
#
# # 1. Spearman by model/filter
#
# plt.figure(figsize=(14, 8))
#
# for model_name in metrics["model"].unique():
#     df = metrics[metrics["model"] == model_name].sort_values("min_profiles")
#     plt.plot(
#         df["min_profiles"].astype(str),
#         df["spearman"],
#         marker="o",
#         linewidth=3,
#         label=model_name
#     )
#
# plt.title("Step 4 Predictability Regression: Spearman by Filter")
# plt.xlabel("Minimum profiles per compound")
# plt.ylabel("Spearman correlation")
# plt.legend()
# save_show(FIG_DIR / "step4_source_normalized_spearman_by_filter.png")
#
#
# # 2. R2 by model/filter
#
# plt.figure(figsize=(14, 8))
#
# for model_name in metrics["model"].unique():
#     df = metrics[metrics["model"] == model_name].sort_values("min_profiles")
#     plt.plot(
#         df["min_profiles"].astype(str),
#         df["r2"],
#         marker="o",
#         linewidth=3,
#         label=model_name
#     )
#
# plt.axhline(0, linestyle="--", linewidth=2)
# plt.title("Step 4 Predictability Regression: R² by Filter")
# plt.xlabel("Minimum profiles per compound")
# plt.ylabel("R²")
# plt.legend()
# save_show(FIG_DIR / "step4_source_normalized_r2_by_filter.png")
#
#
# # 3. Predicted vs actual for best model
#
# best = metrics.sort_values("spearman", ascending=False).iloc[0]
#
# best_model = best["model"]
# best_filter = best["min_profiles"]
#
# best_pred = predictions[
#     (predictions["model"] == best_model) &
#     (predictions["min_profiles"] == best_filter)
# ].copy()
#
# plt.figure(figsize=(10, 8))
# plt.scatter(best_pred["actual"], best_pred["predicted"], alpha=0.65, s=60)
#
# min_val = min(best_pred["actual"].min(), best_pred["predicted"].min())
# max_val = max(best_pred["actual"].max(), best_pred["predicted"].max())
#
# plt.plot([min_val, max_val], [min_val, max_val], linestyle="--", linewidth=2)
#
# plt.title(f"Predicted vs Actual Predictability\n{best_model}, n ≥ {best_filter}")
# plt.xlabel("Actual source-normalized predictability")
# plt.ylabel("Predicted source-normalized predictability")
# plt.figtext(
#     0.02,
#     0.01,
#     f"R²={best['r2']:.3f}, Spearman={best['spearman']:.3f}, MAE={best['mae']:.4f}",
#     fontsize=14
# )
#
# save_show(FIG_DIR / "step4_best_source_normalized_predicted_vs_actual.png")
#
#
# # 4. Residuals for best model
#
# best_pred["residual"] = best_pred["actual"] - best_pred["predicted"]
#
# plt.figure(figsize=(10, 8))
# plt.scatter(best_pred["predicted"], best_pred["residual"], alpha=0.65, s=60)
# plt.axhline(0, linestyle="--", linewidth=2)
#
# plt.title(f"Residuals for Best Step 4 Model\n{best_model}, n ≥ {best_filter}")
# plt.xlabel("Predicted predictability")
# plt.ylabel("Residual: actual - predicted")
#
# save_show(FIG_DIR / "step4_best_source_normalized_residuals.png")
#
# print("Improved Step 4 plots complete.")

# %%
possible_extra_features = [
    "mean_compound_reconstruction_bce",
    "mean_compound_bitwise_accuracy",
    "n_profiles",
]

print("Possible additional features in score table:")

for feature in possible_extra_features:
    print(
        feature,
        "->",
        feature in compound_table.columns
    )
# Out:
# Possible additional features in score table:
# mean_compound_reconstruction_bce -> True
# mean_compound_bitwise_accuracy -> True
# n_profiles -> True

# %%
extra_feature_cols = [
    "mean_compound_reconstruction_bce",
    "mean_compound_bitwise_accuracy",
]

print("Extra feature availability:")

for col in extra_feature_cols:
    print(
        f"{col}:",
        col in compound_table.columns,
        "| missing values:",
        compound_table[col].isna().sum()
    )

X_extra = (
    compound_table[extra_feature_cols]
    .copy()
)

for col in extra_feature_cols:
    X_extra[col] = X_extra[col].fillna(
        X_extra[col].median()
    )

X_extra = X_extra.to_numpy(dtype=np.float32)

X_all_130 = np.concatenate(
    [X_all, X_extra],
    axis=1,
)

print("\n128D embedding matrix:", X_all.shape)
print("Extra feature matrix:", X_extra.shape)
print("Combined feature matrix:", X_all_130.shape)

print("All combined values finite:", np.isfinite(X_all_130).all())

assert X_all_130.shape == (len(compound_table), 130)
assert np.isfinite(X_all_130).all()
# Out:
# Extra feature availability:
# mean_compound_reconstruction_bce: True | missing values: 0
# mean_compound_bitwise_accuracy: True | missing values: 0
#
# 128D embedding matrix: (6605, 128)
# Extra feature matrix: (6605, 2)
# Combined feature matrix: (6605, 130)
# All combined values finite: True

# %%
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import (
    mean_absolute_error,
    r2_score,
)
from sklearn.model_selection import RepeatedKFold
from scipy.stats import spearmanr

RANDOM_STATE = 42

evaluation_thresholds = [
    5,
    10,
    20,
    25,
    50,
    75,
    100,
]

feature_sets = {
    "128D_embedding_only": X_all,
    "130D_embedding_plus_step1_QC": X_all_130,
}

comparison_rows = []

for threshold in evaluation_thresholds:
    mask = (
        compound_table["n_profiles"] >= threshold
    ).to_numpy()

    y = y_all[mask]

    print("\n" + "=" * 90)
    print(
        f"Threshold >= {threshold}: "
        f"{len(y)} compounds"
    )

    # Identical splits
    cv = RepeatedKFold(
        n_splits=5,
        n_repeats=3,
        random_state=RANDOM_STATE,
    )

    splits = list(
        cv.split(np.arange(len(y)))
    )

    for feature_set_name, full_X in feature_sets.items():
        X = full_X[mask]

        print(f"  Feature set: {feature_set_name}")

        for fold_number, (train_idx, test_idx) in enumerate(
            splits,
            start=1,
        ):
            # Match the original successful Step 4 model settings
            model = ExtraTreesRegressor(
                n_estimators=400,
                max_depth=None,
                min_samples_leaf=3,
                random_state=RANDOM_STATE,
                n_jobs=-1,
            )

            model.fit(
                X[train_idx],
                y[train_idx],
            )

            predictions = model.predict(
                X[test_idx]
            )

            r2 = r2_score(
                y[test_idx],
                predictions,
            )

            mae = mean_absolute_error(
                y[test_idx],
                predictions,
            )

            spearman = spearmanr(
                y[test_idx],
                predictions,
            ).correlation

            if np.isnan(spearman):
                spearman = 0.0

            comparison_rows.append({
                "feature_set": feature_set_name,
                "minimum_profiles": threshold,
                "n_compounds": len(y),
                "fold": fold_number,
                "r2": r2,
                "mae": mae,
                "spearman": spearman,
            })

comparison_cv_results = pd.DataFrame(
    comparison_rows
)

print("\nFinished 128D versus 130D comparison.")

display(comparison_cv_results.head())
# Out:
# ==========================================================================================
# Threshold >= 5: 2624 compounds
#   Feature set: 128D_embedding_only
#   Feature set: 130D_embedding_plus_step1_QC
#
# ==========================================================================================
# Threshold >= 10: 1463 compounds
#   Feature set: 128D_embedding_only
#   Feature set: 130D_embedding_plus_step1_QC
#
# ==========================================================================================
# Threshold >= 20: 801 compounds
#   Feature set: 128D_embedding_only
#   Feature set: 130D_embedding_plus_step1_QC
#
# ==========================================================================================
# Threshold >= 25: 700 compounds
#   Feature set: 128D_embedding_only
#   Feature set: 130D_embedding_plus_step1_QC
#
# ==========================================================================================
# Threshold >= 50: 478 compounds
#   Feature set: 128D_embedding_only
#   Feature set: 130D_embedding_plus_step1_QC
#
# ==========================================================================================
# Threshold >= 75: 398 compounds
#   Feature set: 128D_embedding_only
#   Feature set: 130D_embedding_plus_step1_QC
#
# ==========================================================================================
# Threshold >= 100: 349 compounds
#   Feature set: 128D_embedding_only
#   Feature set: 130D_embedding_plus_step1_QC
#
# Finished 128D versus 130D comparison.
#            feature_set  minimum_profiles  n_compounds  fold        r2  \
# 0  128D_embedding_only                 5         2624     1  0.153633
# 1  128D_embedding_only                 5         2624     2  0.177097
# 2  128D_embedding_only                 5         2624     3  0.162956
# 3  128D_embedding_only                 5         2624     4  0.167117
# 4  128D_embedding_only                 5         2624     5  0.181947
#
#         mae  spearman
# 0  0.108659  0.409443
# 1  0.112754  0.467761
# 2  0.107552  0.420609
# 3  0.110419  0.424957
# 4  0.110390  0.503009

# %%
comparison_summary = (
    comparison_cv_results
    .groupby(
        [
            "feature_set",
            "minimum_profiles",
            "n_compounds",
        ],
        as_index=False,
    )
    .agg(
        mean_r2=("r2", "mean"),
        std_r2=("r2", "std"),
        mean_spearman=("spearman", "mean"),
        std_spearman=("spearman", "std"),
        mean_mae=("mae", "mean"),
        std_mae=("mae", "std"),
    )
    .sort_values(
        [
            "minimum_profiles",
            "feature_set",
        ]
    )
    .reset_index(drop=True)
)

display(comparison_summary)
# Out:
#                      feature_set  minimum_profiles  n_compounds   mean_r2  \
# 0            128D_embedding_only                 5         2624  0.170450
# 1   130D_embedding_plus_step1_QC                 5         2624  0.169686
# 2            128D_embedding_only                10         1463  0.157921
# 3   130D_embedding_plus_step1_QC                10         1463  0.156883
# 4            128D_embedding_only                20          801  0.125190
# 5   130D_embedding_plus_step1_QC                20          801  0.126653
# 6            128D_embedding_only                25          700  0.118018
# 7   130D_embedding_plus_step1_QC                25          700  0.118527
# 8            128D_embedding_only                50          478  0.182991
# 9   130D_embedding_plus_step1_QC                50          478  0.180968
# 10           128D_embedding_only                75          398  0.176050
# 11  130D_embedding_plus_step1_QC                75          398  0.172518
# 12           128D_embedding_only               100          349  0.217780
# 13  130D_embedding_plus_step1_QC               100          349  0.219813
#
#       std_r2  mean_spearman  std_spearman  mean_mae   std_mae
# 0   0.018871       0.445535      0.039031  0.109886  0.003756
# 1   0.017173       0.445136      0.036128  0.109912  0.003713
# 2   0.025025       0.422267      0.044726  0.086432  0.003227
# 3   0.021766       0.419735      0.039339  0.086622  0.003257
# 4   0.030427       0.370918      0.053652  0.063515  0.002063
# 5   0.031493       0.370217      0.054897  0.063545  0.002163
# 6   0.049051       0.358774      0.052036  0.059157  0.003618
# 7   0.053195       0.362314      0.065114  0.059110  0.003715
# 8   0.073546       0.414730      0.085764  0.052670  0.002322
# 9   0.079834       0.414491      0.092362  0.052749  0.002257
# 10  0.079449       0.415859      0.080240  0.054478  0.004082
# 11  0.079830       0.405911      0.075374  0.054844  0.003928
# 12  0.085793       0.442397      0.100531  0.055206  0.003077
# 13  0.086077       0.451593      0.097444  0.055060  0.003095

# %%
comparison_wide = comparison_summary.pivot(
    index=[
        "minimum_profiles",
        "n_compounds",
    ],
    columns="feature_set",
    values=[
        "mean_r2",
        "mean_spearman",
        "mean_mae",
    ],
)

comparison_wide.columns = [
    "_".join(col)
    for col in comparison_wide.columns
]

comparison_wide = (
    comparison_wide
    .reset_index()
)

comparison_wide["delta_r2_130_minus_128"] = (
    comparison_wide[
        "mean_r2_130D_embedding_plus_step1_QC"
    ]
    - comparison_wide[
        "mean_r2_128D_embedding_only"
    ]
)

comparison_wide["delta_spearman_130_minus_128"] = (
    comparison_wide[
        "mean_spearman_130D_embedding_plus_step1_QC"
    ]
    - comparison_wide[
        "mean_spearman_128D_embedding_only"
    ]
)

display(comparison_wide)
# Out:
#    minimum_profiles  n_compounds  mean_r2_128D_embedding_only  \
# 0                 5         2624                     0.170450
# 1                10         1463                     0.157921
# 2                20          801                     0.125190
# 3                25          700                     0.118018
# 4                50          478                     0.182991
# 5                75          398                     0.176050
# 6               100          349                     0.217780
#
#    mean_r2_130D_embedding_plus_step1_QC  mean_spearman_128D_embedding_only  \
# 0                              0.169686                           0.445535
# 1                              0.156883                           0.422267
# 2                              0.126653                           0.370918
# 3                              0.118527                           0.358774
# 4                              0.180968                           0.414730
# 5                              0.172518                           0.415859
# 6                              0.219813                           0.442397
#
#    mean_spearman_130D_embedding_plus_step1_QC  mean_mae_128D_embedding_only  \
# 0                                    0.445136                      0.109886
# 1                                    0.419735                      0.086432
# 2                                    0.370217                      0.063515
# 3                                    0.362314                      0.059157
# 4                                    0.414491                      0.052670
# 5                                    0.405911                      0.054478
# 6                                    0.451593                      0.055206
#
#    mean_mae_130D_embedding_plus_step1_QC  delta_r2_130_minus_128  \
# 0                               0.109912               -0.000764
# 1                               0.086622               -0.001038
# 2                               0.063545                0.001463
# 3                               0.059110                0.000509
# 4                               0.052749               -0.002024
# 5                               0.054844               -0.003532
# 6                               0.055060                0.002033
#
#    delta_spearman_130_minus_128
# 0                     -0.000400
# 1                     -0.002532
# 2                     -0.000701
# 3                      0.003540
# 4                     -0.000238
# 5                     -0.009948
# 6                      0.009196

# %%
FOLD_OUTPUT_PATH = (
    PROJECT_ROOT
    / "models"
    / "step4_128_vs_130_features_repeated_cv.csv"
)

SUMMARY_OUTPUT_PATH = (
    PROJECT_ROOT
    / "models"
    / "step4_128_vs_130_features_repeated_cv_summary.csv"
)

WIDE_OUTPUT_PATH = (
    PROJECT_ROOT
    / "models"
    / "step4_128_vs_130_features_threshold_comparison.csv"
)

comparison_cv_results.to_csv(
    FOLD_OUTPUT_PATH,
    index=False,
)

comparison_summary.to_csv(
    SUMMARY_OUTPUT_PATH,
    index=False,
)

comparison_wide.to_csv(
    WIDE_OUTPUT_PATH,
    index=False,
)

print("Saved fold-level results:")
print(FOLD_OUTPUT_PATH)

print("\nSaved summary:")
print(SUMMARY_OUTPUT_PATH)

print("\nSaved direct 128D-versus-130D comparison:")
print(WIDE_OUTPUT_PATH)
# Out:
# Saved fold-level results:
# /Users/mell/predicting-predictability/models/step4_128_vs_130_features_repeated_cv.csv
#
# Saved summary:
# /Users/mell/predicting-predictability/models/step4_128_vs_130_features_repeated_cv_summary.csv
#
# Saved direct 128D-versus-130D comparison:
# /Users/mell/predicting-predictability/models/step4_128_vs_130_features_threshold_comparison.csv

# %%
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import RepeatedKFold
from scipy.stats import spearmanr

RANDOM_STATE = 42

# Use the cleaner representation
X_final = X_all

profile_counts = (
    compound_table["n_profiles"]
    .to_numpy()
)

# Only high-confidence compounds in the test sets
high_confidence_indices = np.where(
    profile_counts >= 100
)[0]

print(
    "High-confidence compounds available for testing:",
    len(high_confidence_indices)
)

training_thresholds = [5, 10, 20, 50, 75, 100]

cv = RepeatedKFold(
    n_splits=5,
    n_repeats=5,
    random_state=RANDOM_STATE,
)

fixed_test_rows = []

for fold_number, (high_train_local, high_test_local) in enumerate(
    cv.split(high_confidence_indices),
    start=1,
):
    # Row positions in compound_table/X_final
    test_indices = high_confidence_indices[high_test_local]

    # Eval on this same test set
    X_test = X_final[test_indices]
    y_test = y_all[test_indices]

    for threshold in training_thresholds:
        eligible_indices = np.where(
            profile_counts >= threshold
        )[0]

        # Remove the fixed high-confidence test compounds from training
        train_indices = np.setdiff1d(
            eligible_indices,
            test_indices,
            assume_unique=False,
        )

        model = ExtraTreesRegressor(
            n_estimators=400,
            max_depth=None,
            min_samples_leaf=3,
            random_state=RANDOM_STATE + fold_number,
            n_jobs=-1,
        )

        model.fit(
            X_final[train_indices],
            y_all[train_indices],
        )

        predictions = model.predict(X_test)

        r2 = r2_score(
            y_test,
            predictions,
        )

        mae = mean_absolute_error(
            y_test,
            predictions,
        )

        spearman = spearmanr(
            y_test,
            predictions,
        ).correlation

        if np.isnan(spearman):
            spearman = 0.0

        fixed_test_rows.append({
            "fold": fold_number,
            "training_minimum_profiles": threshold,
            "n_training_compounds": len(train_indices),
            "n_test_compounds": len(test_indices),
            "r2": r2,
            "spearman": spearman,
            "mae": mae,
        })

fixed_high_conf_test_results = pd.DataFrame(
    fixed_test_rows
)

print("Finished fixed-test-set experiment.")

display(fixed_high_conf_test_results.head())
# Out:
# High-confidence compounds available for testing: 349
# Finished fixed-test-set experiment.
#    fold  training_minimum_profiles  n_training_compounds  n_test_compounds  \
# 0     1                          5                  2554                70
# 1     1                         10                  1393                70
# 2     1                         20                   731                70
# 3     1                         50                   408                70
# 4     1                         75                   328                70
#
#          r2  spearman       mae
# 0 -1.110589  0.238527  0.104621
# 1 -0.151317  0.370239  0.075264
# 2  0.271812  0.518222  0.058053
# 3  0.295124  0.596851  0.053490
# 4  0.300651  0.624670  0.053669

# %%
fixed_high_conf_summary = (
    fixed_high_conf_test_results
    .groupby(
        [
            "training_minimum_profiles",
            "n_training_compounds",
        ],
        as_index=False,
    )
    .agg(
        mean_r2=("r2", "mean"),
        std_r2=("r2", "std"),
        mean_spearman=("spearman", "mean"),
        std_spearman=("spearman", "std"),
        mean_mae=("mae", "mean"),
        std_mae=("mae", "std"),
    )
    .sort_values("training_minimum_profiles")
    .reset_index(drop=True)
)

display(fixed_high_conf_summary)
# Out:
#     training_minimum_profiles  n_training_compounds   mean_r2    std_r2  \
# 0                           5                  2554 -1.718808  0.436130
# 1                           5                  2555 -2.095361  0.428322
# 2                          10                  1393 -0.494829  0.241497
# 3                          10                  1394 -0.709861  0.197617
# 4                          20                   731  0.130412  0.103745
# 5                          20                   732  0.048082  0.051120
# 6                          50                   408  0.214799  0.092456
# 7                          50                   409  0.191101  0.055534
# 8                          75                   328  0.209357  0.096651
# 9                          75                   329  0.194027  0.057237
# 10                        100                   279  0.209036  0.099912
# 11                        100                   280  0.211369  0.047251
#
#     mean_spearman  std_spearman  mean_mae   std_mae
# 0        0.177275      0.090551  0.113394  0.007184
# 1        0.204837      0.039575  0.114447  0.008771
# 2        0.276589      0.095910  0.082165  0.005501
# 3        0.264114      0.094935  0.082432  0.004546
# 4        0.397996      0.088761  0.060687  0.003328
# 5        0.344918      0.070367  0.060950  0.001306
# 6        0.454373      0.103923  0.055312  0.003285
# 7        0.399167      0.095029  0.054055  0.002063
# 8        0.447362      0.105921  0.055291  0.003285
# 9        0.407322      0.093773  0.053342  0.002715
# 10       0.427712      0.119049  0.055813  0.003515
# 11       0.419993      0.066495  0.053205  0.002746

# %%
fixed_high_conf_summary = (
    fixed_high_conf_test_results
    .groupby(
        "training_minimum_profiles",
        as_index=False,
    )
    .agg(
        mean_n_training=("n_training_compounds", "mean"),
        min_n_training=("n_training_compounds", "min"),
        max_n_training=("n_training_compounds", "max"),
        mean_r2=("r2", "mean"),
        std_r2=("r2", "std"),
        mean_spearman=("spearman", "mean"),
        std_spearman=("spearman", "std"),
        mean_mae=("mae", "mean"),
        std_mae=("mae", "std"),
        n_evaluations=("fold", "count"),
    )
    .sort_values("training_minimum_profiles")
    .reset_index(drop=True)
)

display(fixed_high_conf_summary)
# Out:
#    training_minimum_profiles  mean_n_training  min_n_training  max_n_training  \
# 0                          5           2554.2            2554            2555
# 1                         10           1393.2            1393            1394
# 2                         20            731.2             731             732
# 3                         50            408.2             408             409
# 4                         75            328.2             328             329
# 5                        100            279.2             279             280
#
#     mean_r2    std_r2  mean_spearman  std_spearman  mean_mae   std_mae  \
# 0 -1.794119  0.452538       0.182787      0.082939  0.113605  0.007339
# 1 -0.537836  0.245735       0.274094      0.093864  0.082218  0.005236
# 2  0.113946  0.100429       0.387380      0.086787  0.060740  0.003011
# 3  0.210059  0.085877       0.443331      0.102777  0.055061  0.003085
# 4  0.206291  0.089333       0.439354      0.103027  0.054901  0.003226
# 5  0.209503  0.090971       0.426168      0.109393  0.055291  0.003489
#
#    n_evaluations
# 0             25
# 1             25
# 2             25
# 3             25
# 4             25
# 5             25

# %%
FIXED_TEST_RESULTS_PATH = (
    PROJECT_ROOT
    / "models"
    / "step4_fixed_high_confidence_test_fold_results.csv"
)

FIXED_TEST_SUMMARY_PATH = (
    PROJECT_ROOT
    / "models"
    / "step4_fixed_high_confidence_test_summary.csv"
)

fixed_high_conf_test_results.to_csv(
    FIXED_TEST_RESULTS_PATH,
    index=False,
)

fixed_high_conf_summary.to_csv(
    FIXED_TEST_SUMMARY_PATH,
    index=False,
)

print("Saved fold-level results:")
print(FIXED_TEST_RESULTS_PATH)

print("\nSaved fixed-test summary:")
print(FIXED_TEST_SUMMARY_PATH)
# Out:
# Saved fold-level results:
# /Users/mell/predicting-predictability/models/step4_fixed_high_confidence_test_fold_results.csv
#
# Saved fixed-test summary:
# /Users/mell/predicting-predictability/models/step4_fixed_high_confidence_test_summary.csv

# %%
baseline_per_fold = (
    fixed_high_conf_test_results[
        fixed_high_conf_test_results[
            "training_minimum_profiles"
        ] == 100
    ][
        ["fold", "r2", "spearman", "mae"]
    ]
    .rename(
        columns={
            "r2": "baseline_r2",
            "spearman": "baseline_spearman",
            "mae": "baseline_mae",
        }
    )
)

paired_results = fixed_high_conf_test_results.merge(
    baseline_per_fold,
    on="fold",
    how="left",
    validate="many_to_one",
)

paired_results["delta_r2_vs_train100"] = (
    paired_results["r2"]
    - paired_results["baseline_r2"]
)

paired_results["delta_spearman_vs_train100"] = (
    paired_results["spearman"]
    - paired_results["baseline_spearman"]
)

paired_results["delta_mae_vs_train100"] = (
    paired_results["mae"]
    - paired_results["baseline_mae"]
)

paired_summary = (
    paired_results
    .groupby(
        "training_minimum_profiles",
        as_index=False,
    )
    .agg(
        mean_delta_r2=(
            "delta_r2_vs_train100",
            "mean",
        ),
        std_delta_r2=(
            "delta_r2_vs_train100",
            "std",
        ),
        mean_delta_spearman=(
            "delta_spearman_vs_train100",
            "mean",
        ),
        std_delta_spearman=(
            "delta_spearman_vs_train100",
            "std",
        ),
        mean_delta_mae=(
            "delta_mae_vs_train100",
            "mean",
        ),
        std_delta_mae=(
            "delta_mae_vs_train100",
            "std",
        ),
    )
    .sort_values("training_minimum_profiles")
    .reset_index(drop=True)
)

display(paired_summary)
# Out:
#    training_minimum_profiles  mean_delta_r2  std_delta_r2  \
# 0                          5      -2.003622      0.427199
# 1                         10      -0.747339      0.229032
# 2                         20      -0.095557      0.071612
# 3                         50       0.000556      0.033054
# 4                         75      -0.003212      0.024781
# 5                        100       0.000000      0.000000
#
#    mean_delta_spearman  std_delta_spearman  mean_delta_mae  std_delta_mae
# 0            -0.243380            0.123192        0.058313       0.007215
# 1            -0.152074            0.113474        0.026927       0.005158
# 2            -0.038788            0.072765        0.005448       0.002816
# 3             0.017164            0.057313       -0.000231       0.001567
# 4             0.013186            0.039527       -0.000391       0.001208
# 5             0.000000            0.000000        0.000000       0.000000

# %%
# Save all fixed high-confidence test experiment outputs

from pathlib import Path

MODEL_DIR = PROJECT_ROOT / "models"
MODEL_DIR.mkdir(parents=True, exist_ok=True)

# Output paths
FIXED_TEST_RESULTS_PATH = (
    MODEL_DIR
    / "step4_fixed_high_confidence_test_fold_results.csv"
)

FIXED_TEST_SUMMARY_PATH = (
    MODEL_DIR
    / "step4_fixed_high_confidence_test_summary.csv"
)

PAIRED_RESULTS_PATH = (
    MODEL_DIR
    / "step4_fixed_high_confidence_test_paired_results.csv"
)

PAIRED_SUMMARY_PATH = (
    MODEL_DIR
    / "step4_fixed_high_confidence_test_paired_summary.csv"
)

# Save results
fixed_high_conf_test_results.to_csv(
    FIXED_TEST_RESULTS_PATH,
    index=False,
)

# Save corrected summary with one row per threshold
fixed_high_conf_summary.to_csv(
    FIXED_TEST_SUMMARY_PATH,
    index=False,
)

# Save comparisons against the >=100 baseline
paired_results.to_csv(
    PAIRED_RESULTS_PATH,
    index=False,
)

# Save summarized paired differences
paired_summary.to_csv(
    PAIRED_SUMMARY_PATH,
    index=False,
)

print("Saved fold-level results:")
print(FIXED_TEST_RESULTS_PATH)

print("\nSaved corrected threshold summary:")
print(FIXED_TEST_SUMMARY_PATH)

print("\nSaved paired fold comparisons:")
print(PAIRED_RESULTS_PATH)

print("\nSaved paired comparison summary:")
print(PAIRED_SUMMARY_PATH)

print("\nSaved shapes:")
print(
    "Fold-level results:",
    fixed_high_conf_test_results.shape
)
print(
    "Threshold summary:",
    fixed_high_conf_summary.shape
)
print(
    "Paired fold results:",
    paired_results.shape
)
print(
    "Paired summary:",
    paired_summary.shape
)
# Out:
# Saved fold-level results:
# /Users/mell/predicting-predictability/models/step4_fixed_high_confidence_test_fold_results.csv
#
# Saved corrected threshold summary:
# /Users/mell/predicting-predictability/models/step4_fixed_high_confidence_test_summary.csv
#
# Saved paired fold comparisons:
# /Users/mell/predicting-predictability/models/step4_fixed_high_confidence_test_paired_results.csv
#
# Saved paired comparison summary:
# /Users/mell/predicting-predictability/models/step4_fixed_high_confidence_test_paired_summary.csv
#
# Saved shapes:
# Fold-level results: (150, 7)
# Threshold summary: (6, 11)
# Paired fold results: (150, 13)
# Paired summary: (6, 7)

# %%
import numpy as np
import matplotlib.pyplot as plt

FIG_DIR = (
    PROJECT_ROOT
    / "figures"
    / "step4_predictability_regression"
)

FIG_DIR.mkdir(
    parents=True,
    exist_ok=True
)

plot_df = (
    fixed_high_conf_summary
    .sort_values("training_minimum_profiles")
    .reset_index(drop=True)
)

x = np.arange(len(plot_df))
labels = plot_df["training_minimum_profiles"].astype(str)

plt.figure(figsize=(13, 8))

plt.errorbar(
    x,
    plot_df["mean_r2"],
    yerr=plot_df["std_r2"],
    marker="o",
    linewidth=3,
    capsize=5,
    label="R²",
)

plt.errorbar(
    x,
    plot_df["mean_spearman"],
    yerr=plot_df["std_spearman"],
    marker="o",
    linewidth=3,
    capsize=5,
    label="Spearman",
)

plt.axhline(
    0,
    linestyle="--",
    linewidth=2,
)

plt.xticks(x, labels)

plt.title(
    "Adding Low-Profile Compounds Does Not Improve\n"
    "Generalization to High-Confidence Compounds"
)

plt.xlabel(
    "Minimum profiles required for inclusion in training"
)

plt.ylabel("Cross-validated performance")

plt.legend()

plt.figtext(
    0.02,
    0.01,
    (
        "All models were evaluated on the same held-out compounds "
        "with n_profiles ≥ 100. Error bars show standard deviation "
        "across repeated folds."
    ),
    fontsize=12,
)

plt.tight_layout()

performance_figure_path = (
    FIG_DIR
    / "step4_fixed_high_confidence_test_performance.png"
)

plt.savefig(
    performance_figure_path,
    dpi=300,
    bbox_inches="tight",
)

plt.show()

print("Saved:", performance_figure_path)
# Out:
# Saved: /Users/mell/predicting-predictability/figures/step4_predictability_regression/step4_fixed_high_confidence_test_performance.png

# %%
plt.figure(figsize=(12, 8))

plt.bar(
    x,
    plot_df["mean_n_training"],
)

plt.xticks(x, labels)

plt.title(
    "Relaxing the Profile Threshold Expands the Training Set"
)

plt.xlabel(
    "Minimum profiles required for inclusion in training"
)

plt.ylabel(
    "Mean number of training compounds per fold"
)

for position, value in zip(
    x,
    plot_df["mean_n_training"],
):
    plt.text(
        position,
        value,
        f"{value:.0f}",
        ha="center",
        va="bottom",
        fontsize=12,
    )

plt.figtext(
    0.02,
    0.01,
    (
        "The largest training sets contain many compounds whose "
        "Step 3 predictability labels are estimated from relatively "
        "few transcriptional profiles."
    ),
    fontsize=12,
)

plt.tight_layout()

training_size_figure_path = (
    FIG_DIR
    / "step4_training_size_by_profile_threshold.png"
)

plt.savefig(
    training_size_figure_path,
    dpi=300,
    bbox_inches="tight",
)

plt.show()

print("Saved:", training_size_figure_path)
# Out:
# Saved: /Users/mell/predicting-predictability/figures/step4_predictability_regression/step4_training_size_by_profile_threshold.png

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({
    "font.size": 20,
    "axes.titlesize": 30,
    "axes.labelsize": 25,
    "xtick.labelsize": 21,
    "ytick.labelsize": 21,
    "legend.fontsize": 21,
    "figure.titlesize": 30,
})

# %%
import numpy as np
import matplotlib.pyplot as plt

FIG_DIR = (
    PROJECT_ROOT
    / "figures"
    / "step4_predictability_regression"
)

FIG_DIR.mkdir(
    parents=True,
    exist_ok=True
)

plot_df = (
    fixed_high_conf_summary
    .sort_values("training_minimum_profiles")
    .reset_index(drop=True)
)

x = np.arange(len(plot_df))
labels = plot_df["training_minimum_profiles"].astype(str)

plt.figure(figsize=(16, 10))

plt.errorbar(
    x,
    plot_df["mean_r2"],
    yerr=plot_df["std_r2"],
    marker="o",
    markersize=11,
    linewidth=4,
    capsize=7,
    capthick=2.5,
    label="R²",
)

plt.errorbar(
    x,
    plot_df["mean_spearman"],
    yerr=plot_df["std_spearman"],
    marker="o",
    markersize=11,
    linewidth=4,
    capsize=7,
    capthick=2.5,
    label="Spearman",
)

plt.axhline(
    0,
    linestyle="--",
    linewidth=2.5,
)

plt.xticks(x, labels)

plt.title(
    "Low-Profile Compounds Reduce Model Performance",
    fontsize=30,
    pad=22,
)

plt.xlabel(
    "Minimum profiles required for inclusion in training",
    fontsize=25,
    labelpad=15,
)

plt.ylabel(
    "Cross-validated performance",
    fontsize=25,
    labelpad=15,
)

plt.tick_params(
    axis="both",
    labelsize=21,
)

plt.legend(
    fontsize=21,
    frameon=True,
)

plt.figtext(
    0.02,
    0.01,
    (
        "All models were evaluated on the same held-out compounds "
        "with n_profiles ≥ 100. Error bars show standard deviation "
        "across repeated folds."
    ),
    fontsize=15,
)

plt.tight_layout(rect=[0, 0.06, 1, 1])

performance_figure_path = (
    FIG_DIR
    / "step4_fixed_high_confidence_test_performance_largefont.png"
)

plt.savefig(
    performance_figure_path,
    dpi=300,
    bbox_inches="tight",
)

plt.show()

print("Saved:", performance_figure_path)
# Out:
# Saved: /Users/mell/predicting-predictability/figures/step4_predictability_regression/step4_fixed_high_confidence_test_performance_largefont.png

# %%
plt.figure(figsize=(16, 10))

plt.bar(
    x,
    plot_df["mean_n_training"],
)

plt.xticks(
    x,
    labels,
    fontsize=21,
)

plt.yticks(
    fontsize=21,
)

plt.title(
    "Relaxing the Profile Threshold Expands the Training Set",
    fontsize=30,
    pad=22,
)

plt.xlabel(
    "Minimum profiles required for inclusion in training",
    fontsize=25,
    labelpad=15,
)

plt.ylabel(
    "Mean number of training compounds per fold",
    fontsize=25,
    labelpad=15,
)

for position, value in zip(
    x,
    plot_df["mean_n_training"],
):
    plt.text(
        position,
        value,
        f"{value:.0f}",
        ha="center",
        va="bottom",
        fontsize=17,
        fontweight="bold",
    )

plt.figtext(
    0.02,
    0.01,
    (
        "The largest training sets contain many compounds whose "
        "Step 3 predictability labels are estimated from relatively "
        "few transcriptional profiles."
    ),
    fontsize=15,
)

plt.tight_layout(rect=[0, 0.06, 1, 1])

training_size_figure_path = (
    FIG_DIR
    / "step4_training_size_by_profile_threshold_largefont.png"
)

plt.savefig(
    training_size_figure_path,
    dpi=300,
    bbox_inches="tight",
)

plt.show()

print("Saved:", training_size_figure_path)
# Out:
# Saved: /Users/mell/predicting-predictability/figures/step4_predictability_regression/step4_training_size_by_profile_threshold_largefont.png

# %%
import numpy as np
import matplotlib.pyplot as plt

FIG_DIR = (
    PROJECT_ROOT
    / "figures"
    / "step4_predictability_regression"
)

FIG_DIR.mkdir(
    parents=True,
    exist_ok=True,
)

plot_df = (
    fixed_high_conf_summary
    .sort_values("training_minimum_profiles")
    .reset_index(drop=True)
)

x = np.arange(len(plot_df))

# Show threshold and mean training-set size
labels = [
    (
        f"≥{int(row['training_minimum_profiles'])}\n"
        f"(n={int(round(row['mean_n_training'])):,})"
    )
    for _, row in plot_df.iterrows()
]

fig, ax = plt.subplots(figsize=(16, 10))

ax.errorbar(
    x,
    plot_df["mean_r2"],
    yerr=plot_df["std_r2"],
    marker="o",
    markersize=11,
    linewidth=4,
    capsize=7,
    capthick=2.5,
    label="R²",
)

ax.errorbar(
    x,
    plot_df["mean_spearman"],
    yerr=plot_df["std_spearman"],
    marker="o",
    markersize=11,
    linewidth=4,
    capsize=7,
    capthick=2.5,
    label="Spearman",
)

ax.axhline(
    0,
    linestyle="--",
    linewidth=2.5,
)

ax.set_xticks(x)
ax.set_xticklabels(
    labels,
    fontsize=20,
)

ax.tick_params(
    axis="y",
    labelsize=21,
)

ax.set_title(
    "Training on Low-Profile Compounds\n" 
    "Reduces Performance",
    fontsize=30,
    pad=22,
)

ax.set_xlabel(
    "Minimum profiles required for training\n"
    "(mean training compounds per fold shown in parentheses)",
    fontsize=23,
    labelpad=16,
)

# Split across two lines so it stays inside the figure
ax.set_ylabel(
    "Performance on held-out\n"
    "high-confidence compounds",
    fontsize=23,
    labelpad=12,
)

ax.legend(
    fontsize=21,
    frameon=True,
    loc="lower right",
)

fig.text(
    0.04,
    0.025,
    (
        "All models were evaluated on the same held-out compounds with "
        "n_profiles ≥ 100. Increasing the training set from about 279 to "
        "2,554 compounds did not improve performance because the additional "
        "compounds had less reliable Step 3 labels. Error bars show standard "
        "deviation across repeated folds."
    ),
    fontsize=14,
    wrap=True,
)

# Reserve space for the y-axis title, x-axis labels, and caption
fig.subplots_adjust(
    left=0.18,
    right=0.98,
    top=0.88,
    bottom=0.25,
)

performance_figure_path = (
    FIG_DIR
    / "step4_performance_by_training_profile_threshold_largefont.png"
)

plt.savefig(
    performance_figure_path,
    dpi=300,
    bbox_inches="tight",
)

plt.show()

print("Saved:", performance_figure_path)
# Out:
# Saved: /Users/mell/predicting-predictability/figures/step4_predictability_regression/step4_performance_by_training_profile_threshold_largefont.png

# %%
import numpy as np
import matplotlib.pyplot as plt

FIG_DIR = (
    PROJECT_ROOT
    / "figures"
    / "step4_predictability_regression"
)

FIG_DIR.mkdir(
    parents=True,
    exist_ok=True,
)

plot_df = (
    fixed_high_conf_summary
    .sort_values("training_minimum_profiles")
    .reset_index(drop=True)
)

x = np.arange(len(plot_df))
labels = plot_df["training_minimum_profiles"].astype(str)

plt.figure(figsize=(16, 10))

plt.bar(
    x,
    plot_df["mean_n_training"],
)

plt.xticks(
    x,
    labels,
    fontsize=22,
)

plt.yticks(fontsize=22)

plt.title(
    "Training Set Size by Minimum Profile Threshold",
    fontsize=32,
    pad=22,
)

plt.xlabel(
    "Minimum profiles required for inclusion in training",
    fontsize=25,
    labelpad=16,
)

plt.ylabel(
    "Mean number of training compounds per fold",
    fontsize=25,
    labelpad=16,
)

# Add the training-set size above each bar
for position, value in zip(
    x,
    plot_df["mean_n_training"],
):
    plt.text(
        position,
        value,
        f"{value:.0f}",
        ha="center",
        va="bottom",
        fontsize=19,
        fontweight="bold",
    )

plt.tight_layout()

training_size_figure_path = (
    FIG_DIR
    / "step4_training_size_by_profile_threshold_largefont.png"
)

plt.savefig(
    training_size_figure_path,
    dpi=300,
    bbox_inches="tight",
)

plt.show()

print("Saved:", training_size_figure_path)
# Out:
# Saved: /Users/mell/predicting-predictability/figures/step4_predictability_regression/step4_training_size_by_profile_threshold_largefont.png

# %%
# Step 4 follow-up: adjust predictability scores for profile count

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import Ridge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

profile_count_feature = np.log1p(
    compound_table["n_profiles"].to_numpy(dtype=np.float32)
).reshape(-1, 1)

observed_predictability = compound_table[
    "source_normalized_inverted_score"
].to_numpy(dtype=np.float32)

print("Profile-count feature shape:", profile_count_feature.shape)
print("Predictability target shape:", observed_predictability.shape)

print(
    "Spearman correlation between profile count and predictability:",
    compound_table["n_profiles"].corr(
        compound_table["source_normalized_inverted_score"],
        method="spearman",
    ),
)
# Out:
# Profile-count feature shape: (6605, 1)
# Predictability target shape: (6605,)
# Spearman correlation between profile count and predictability: 0.3370542120538177

# %%
import numpy as np
import pandas as pd

from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import Ridge
from sklearn.metrics import (
    mean_absolute_error,
    r2_score,
)
from sklearn.model_selection import RepeatedKFold
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import (
    PolynomialFeatures,
    StandardScaler,
)
from scipy.stats import spearmanr

RANDOM_STATE = 42

X_structure = X_all

profile_counts = (
    compound_table["n_profiles"]
    .to_numpy(dtype=np.float32)
)

raw_scores = (
    compound_table["source_normalized_inverted_score"]
    .to_numpy(dtype=np.float32)
)

log_profile_counts = np.log1p(
    profile_counts
).reshape(-1, 1)

training_thresholds = [
    5,
    10,
    20,
    50,
    75,
    100,
]

# The test sets always contain only high-confidence compounds
high_confidence_indices = np.where(
    profile_counts >= 100
)[0]

print(
    "High-confidence compounds available for testing:",
    len(high_confidence_indices),
)

cv = RepeatedKFold(
    n_splits=5,
    n_repeats=5,
    random_state=RANDOM_STATE,
)

adjusted_result_rows = []

for fold_number, (
    high_train_local,
    high_test_local,
) in enumerate(
    cv.split(high_confidence_indices),
    start=1,
):
    test_indices = high_confidence_indices[
        high_test_local
    ]

    for threshold in training_thresholds:
        eligible_indices = np.where(
            profile_counts >= threshold
        )[0]

        # Prevent held-out compounds from entering training
        train_indices = np.setdiff1d(
            eligible_indices,
            test_indices,
            assume_unique=False,
        )

        # Fit expected predictability from profile count
        # using training compounds only
        adjustment_model = make_pipeline(
            PolynomialFeatures(
                degree=2,
                include_bias=False,
            ),
            StandardScaler(),
            Ridge(alpha=1.0),
        )

        adjustment_model.fit(
            log_profile_counts[train_indices],
            raw_scores[train_indices],
        )

        expected_train_scores = adjustment_model.predict(
            log_profile_counts[train_indices]
        )

        expected_test_scores = adjustment_model.predict(
            log_profile_counts[test_indices]
        )

        adjusted_train_scores = (
            raw_scores[train_indices]
            - expected_train_scores
        )

        adjusted_test_scores = (
            raw_scores[test_indices]
            - expected_test_scores
        )

        # Train the structure-only Step 4 model
        model = ExtraTreesRegressor(
            n_estimators=400,
            max_depth=None,
            min_samples_leaf=3,
            random_state=RANDOM_STATE + fold_number,
            n_jobs=-1,
        )

        model.fit(
            X_structure[train_indices],
            adjusted_train_scores,
        )

        predictions = model.predict(
            X_structure[test_indices]
        )

        r2 = r2_score(
            adjusted_test_scores,
            predictions,
        )

        mae = mean_absolute_error(
            adjusted_test_scores,
            predictions,
        )

        spearman = spearmanr(
            adjusted_test_scores,
            predictions,
        ).correlation

        if np.isnan(spearman):
            spearman = 0.0

        remaining_profile_correlation = spearmanr(
            profile_counts[train_indices],
            adjusted_train_scores,
        ).correlation

        adjusted_result_rows.append({
            "fold": fold_number,
            "training_minimum_profiles": threshold,
            "n_training_compounds": len(train_indices),
            "n_test_compounds": len(test_indices),
            "r2": r2,
            "spearman": spearman,
            "mae": mae,
            "remaining_train_profile_correlation":
                remaining_profile_correlation,
        })

adjusted_fixed_test_results = pd.DataFrame(
    adjusted_result_rows
)

print("Finished profile-count-adjusted experiment.")

display(adjusted_fixed_test_results.head())
# Out:
# High-confidence compounds available for testing: 349
# Finished profile-count-adjusted experiment.
#    fold  training_minimum_profiles  n_training_compounds  n_test_compounds  \
# 0     1                          5                  2554                70
# 1     1                         10                  1393                70
# 2     1                         20                   731                70
# 3     1                         50                   408                70
# 4     1                         75                   328                70
#
#          r2  spearman       mae  remaining_train_profile_correlation
# 0 -0.524731  0.102196  0.077893                            -0.046793
# 1 -0.149928  0.282442  0.064251                            -0.038116
# 2  0.161285  0.566442  0.054880                            -0.033445
# 3  0.255062  0.602345  0.053344                            -0.026947
# 4  0.236682  0.568297  0.054442                            -0.044603

# %%
adjusted_fixed_test_summary = (
    adjusted_fixed_test_results
    .groupby(
        "training_minimum_profiles",
        as_index=False,
    )
    .agg(
        mean_n_training=(
            "n_training_compounds",
            "mean",
        ),
        mean_r2=("r2", "mean"),
        std_r2=("r2", "std"),
        mean_spearman=("spearman", "mean"),
        std_spearman=("spearman", "std"),
        mean_mae=("mae", "mean"),
        std_mae=("mae", "std"),
        mean_remaining_profile_correlation=(
            "remaining_train_profile_correlation",
            "mean",
        ),
        n_evaluations=("fold", "count"),
    )
    .sort_values(
        "training_minimum_profiles"
    )
    .reset_index(drop=True)
)

display(adjusted_fixed_test_summary)
# Out:
#    training_minimum_profiles  mean_n_training   mean_r2    std_r2  \
# 0                          5           2554.2 -0.481928  0.181787
# 1                         10           1393.2 -0.129395  0.142238
# 2                         20            731.2  0.076206  0.102609
# 3                         50            408.2  0.186123  0.095285
# 4                         75            328.2  0.177130  0.100124
# 5                        100            279.2  0.165163  0.082922
#
#    mean_spearman  std_spearman  mean_mae   std_mae  \
# 0       0.091167      0.085448  0.071095  0.003624
# 1       0.215114      0.101572  0.061754  0.003714
# 2       0.383725      0.107704  0.054979  0.002755
# 3       0.442150      0.102575  0.052322  0.002886
# 4       0.427279      0.109491  0.052268  0.003230
# 5       0.401895      0.104631  0.052358  0.003549
#
#    mean_remaining_profile_correlation  n_evaluations
# 0                           -0.046344             25
# 1                           -0.037359             25
# 2                           -0.032276             25
# 3                           -0.023057             25
# 4                           -0.042347             25
# 5                           -0.026799             25

# %%
# Step 4 (potential) final model: train using compounds with at least 50 profiles

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import ExtraTreesRegressor

FINAL_MIN_PROFILES = 50
FINAL_TARGET = "source_normalized_inverted_score"
RANDOM_STATE = 42

final_mask = (
    compound_table["n_profiles"] >= FINAL_MIN_PROFILES
).to_numpy()

X_final_train = X_all[final_mask]

y_final_train = (
    compound_table.loc[
        final_mask,
        FINAL_TARGET,
    ]
    .to_numpy(dtype=np.float32)
)

final_training_table = (
    compound_table.loc[
        final_mask,
        [
            "compound_embedding_row_index",
            "compound_name",
            "n_profiles",
            FINAL_TARGET,
        ],
    ]
    .reset_index(drop=True)
)

print("Final training compounds:", len(final_training_table))
print("Feature matrix shape:", X_final_train.shape)
print("Target shape:", y_final_train.shape)

print(
    "Minimum profile count:",
    final_training_table["n_profiles"].min(),
)

print(
    "Median profile count:",
    final_training_table["n_profiles"].median(),
)

assert X_final_train.shape[0] == len(final_training_table)
assert X_final_train.shape[1] == 128
assert np.isfinite(X_final_train).all()
assert np.isfinite(y_final_train).all()

final_model = ExtraTreesRegressor(
    n_estimators=400,
    max_depth=None,
    min_samples_leaf=3,
    random_state=RANDOM_STATE,
    n_jobs=-1,
)

final_model.fit(
    X_final_train,
    y_final_train,
)

print("\nFinal Extra Trees model trained successfully.")
# Out:
# Final training compounds: 478
# Feature matrix shape: (478, 128)
# Target shape: (478,)
# Minimum profile count: 50
# Median profile count: 140.0
#
# Final Extra Trees model trained successfully.

# %%
import joblib
from pathlib import Path

MODEL_DIR = PROJECT_ROOT / "models"
MODEL_DIR.mkdir(
    parents=True,
    exist_ok=True,
)

STEP3_DIR = DATA_DIR / "step3_multimodal"
STEP3_DIR.mkdir(
    parents=True,
    exist_ok=True,
)

FINAL_MODEL_PATH = (
    MODEL_DIR
    / "step4_final_extra_trees_n50.joblib"
)

FINAL_TRAINING_TABLE_PATH = (
    STEP3_DIR
    / "step4_final_extra_trees_n50_training_compounds.csv"
)

FINAL_MODEL_SUMMARY_PATH = (
    MODEL_DIR
    / "step4_final_extra_trees_n50_summary.txt"
)

model_bundle = {
    "model": final_model,
    "target": FINAL_TARGET,
    "minimum_profiles": FINAL_MIN_PROFILES,
    "n_training_compounds": len(final_training_table),
    "n_features": X_final_train.shape[1],
    "feature_representation": "Step 1 compound autoencoder 128D embedding",
    "random_state": RANDOM_STATE,
    "model_parameters": final_model.get_params(),
}

joblib.dump(
    model_bundle,
    FINAL_MODEL_PATH,
)

final_training_table.to_csv(
    FINAL_TRAINING_TABLE_PATH,
    index=False,
)

summary_text = f"""
Step 4 final compound predictability model

Model:
ExtraTreesRegressor

Input representation:
Final Step 1 128D compound autoencoder embeddings

Target:
{FINAL_TARGET}

Minimum profiles required:
{FINAL_MIN_PROFILES}

Number of training compounds:
{len(final_training_table)}

Number of input features:
{X_final_train.shape[1]}

Model parameters:
n_estimators = 400
max_depth = None
min_samples_leaf = 3
random_state = {RANDOM_STATE}

Selection rationale:
Including compounds with fewer than
approx 50 profiles reduced performance on held-out high-confidence
compounds. The >=50 condition kept approx the same performance
as the >=100 condition while allowing more compounds into training.
""".strip()

FINAL_MODEL_SUMMARY_PATH.write_text(
    summary_text
)

print("Saved final model:")
print(FINAL_MODEL_PATH)

print("\nSaved training-compound table:")
print(FINAL_TRAINING_TABLE_PATH)

print("\nSaved model summary:")
print(FINAL_MODEL_SUMMARY_PATH)
# Out:
# Saved final model:
# /Users/mell/predicting-predictability/models/step4_final_extra_trees_n50.joblib
#
# Saved training-compound table:
# /Users/mell/predicting-predictability/data/step3_multimodal/step4_final_extra_trees_n50_training_compounds.csv
#
# Saved model summary:
# /Users/mell/predicting-predictability/models/step4_final_extra_trees_n50_summary.txt
